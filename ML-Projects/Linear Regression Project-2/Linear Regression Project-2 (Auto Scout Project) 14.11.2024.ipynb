# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>Lineer Regression Project 2 (Auto Scout)</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Whatsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [LinkedIn](https://www.linkedin.com/company/techproeducation/mycompany/) |

# %% [markdown]
# # About the Dataset
#
# - **Auto Scout** datası, 2019'da çevrimiçi otomobil ticaret şirketi [AutoScout24](https://www.autoscout24.com) 'den alınmıştır ve 9 farklı otomobil modelinin birçok özelliğini içermektedir.
#
# - Bu projede, algoritmalar için zaten önceden işlenmiş ve hazırlanmış veri setini kullanacağız.
#
# - Bu projenin amacı, makine öğrenimi algoritmalarını anlamaktır. Bu nedenle, düzenlenmiş veri üzerinde çalışacağınız için yoğun bir EDA sürecine ihtiyaç duymayacağız.
#
# - Bu senaryoda, regresyon algoritmalarını kullanarak otomobil fiyatlarını tahmin edeceğiz.
#
# - Başlarken gerekli kütüphaneleri içe aktarmamız gerekecek. Ayrıca modellemeye geçmeden önce birkaç ön işleme yapmamız gerekecek.
#
# - Daha sonra sırasıyla Lineer Regresyon, Ridge Regresyon, Lasso Regresyon ve Elastic-Net algoritmalarını uygulayacağız.
#
# - Modellerimizin başarısını regresyon hata metrikleriyle ve cross validation yöntemiyle ölçebiliriz.
#
# - Daha iyi sonuçlar için, hiperparametre ayarlama yaparak modellerinizin başarısını artırmaya çalışağız.
#
# - Model için feature ların önemlerini belirleyip kaynak tasarrufu için modelimizi en önemli feature lar ile ayarlayacağız.
#
# - Son olarak, algoritmaların performanslarını karşılaştıracağız.
#
# - Ayrıca en başarılı tahmin oranına sahip olan algoritma üzerinde daha fazla çalışabilirsiniz.
#
#
# 1. **make_model**: Araçların marka ve model bilgisini içerir.
# 2. **body_type**: Araçların gövde tipini belirtir (örn. sedan, hatchback).
# 3. **price**: Araçların fiyat bilgisini içerir.
# 4. **vat**: KDV bilgisini içerir (genellikle araç satışlarında önemlidir).
# 5. **km**: Araçların kilometre bilgisini içerir.
# 6. **Type**: Araç türünü belirtir (örn. yeni, ikinci el).
# 7. **Fuel**: Kullanılan yakıt türünü belirtir (örn. benzin, dizel).
# 8. **Gears**: Araçların vites sayısını içerir.
# 9. **Comfort_Convenience**: Araçların konfor ve kolaylık özelliklerini içerir.
# 10. **Entertainment_Media**: Eğlence ve medya özelliklerini içerir.
# 11. **Extras**: Araçların ekstra özelliklerini içerir.
# 12. **Safety_Security**: Güvenlik özelliklerini içerir.
# 13. **age**: Araçların yaşı.
# 14. **Previous_Owners**: Araçların önceki sahip sayısını içerir.
# 15. **hp_kW**: Araçların beygir gücünü kilowatt cinsinden içerir.
# 16. **Inspection_new**: Araçların yeni muayene bilgisini içerir.
# 17. **Paint_Type**: Araçların boya tipini içerir.
# 18. **Upholstery_type**: Araçların iç döşeme tipini içerir.
# 19. **Gearing_Type**: Araçların şanzıman tipini içerir.
# 20. **Displacement_cc**: Motor hacmini santimetreküp (cc) cinsinden belirtir.
# 21. **Weight_kg**: Araçların ağırlığını kilogram cinsinden belirtir.
# 22. **Drive_chain**: Araçların çekiş türünü belirtir (örn. ön çekiş, arka çekiş).
# 23. **cons_comb**: Araçların kombinasyonel yakıt tüketimini litresi 100 kilometre başına belirtir.
#
# **------------**
#
# 1. **make_model**: Contains the make and model information of the vehicles.
# 2. **body_type**: Indicates the body type of the vehicles (e.g., sedan, hatchback).
# 3. **price**: Contains the price information of the vehicles.
# 4. **vat**: Contains value-added tax (VAT) information (often important in vehicle sales).
# 5. **km**: Contains the mileage information of the vehicles.
# 6. **Type**: Indicates the type of the vehicle (e.g., new, used).
# 7. **Fuel**: Indicates the type of fuel used (e.g., petrol, diesel).
# 8. **Gears**: Contains the number of gears in the vehicles.
# 9. **Comfort_Convenience**: Contains the comfort and convenience features of the vehicles.
# 10. **Entertainment_Media**: Contains entertainment and media features.
# 11. **Extras**: Contains the extra features of the vehicles.
# 12. **Safety_Security**: Contains safety features.
# 13. **age**: The age of the vehicles.
# 14. **Previous_Owners**: Contains the number of previous owners of the vehicles.
# 15. **hp_kW**: Contains the horsepower of the vehicles in kilowatts.
# 16. **Inspection_new**: Contains information about whether the vehicle has a new inspection.
# 17. **Paint_Type**: Contains the type of paint of the vehicles.
# 18. **Upholstery_type**: Contains the type of upholstery in the vehicles.
# 19. **Gearing_Type**: Indicates the type of transmission in the vehicles.
# 20. **Displacement_cc**: Indicates the engine displacement in cubic centimeters (cc).
# 21. **Weight_kg**: Indicates the weight of the vehicles in kilograms.
# 22. **Drive_chain**: Indicates the type of drive train in the vehicles (e.g., front-wheel drive, rear-wheel drive).
# 23. **cons_comb**: Indicates the combined fuel consumption of the vehicles in liters per 100 kilometers.

# %% [markdown]
# # Tasks
#
# - 1. Import Modules, Load Data and Data Review
#
# - 2. EDA
#
# - 3. Train | Test Split
#
# - 4. Implement Linear Regression
#
# - 5. Implement Ridge Regression
#
# - 6. Implement Lasso Regression
#
# - 7. Implement Elastic-Net
#
# - 8. Visually Compare Models Performance In a Graph
#
# - 9. Feature Importance
#
# - 10. Compare Models Performance
#
# - 11. Final Model
#
# - 12. Prediction

# %% [markdown]
# # Import Modules, Load Data and Data Review

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
 
# %matplotlib inline  

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("final_scout_not_dummy.csv")
df1 = df.copy()

# %%
df.head()
# Out:
#   make_model body_type  price               vat       km  Type     Fuel  \
# 0    Audi A1    Sedans  15770    VAT deductible  56013.0  Used   Diesel
# 1    Audi A1    Sedans  14500  Price negotiable  80000.0  Used  Benzine
# 2    Audi A1    Sedans  14640    VAT deductible  83450.0  Used   Diesel
# 3    Audi A1    Sedans  14500    VAT deductible  73000.0  Used   Diesel
# 4    Audi A1    Sedans  16790    VAT deductible  16200.0  Used   Diesel
#
#    Gears                                Comfort_Convenience  \
# 0    7.0  Air conditioning,Armrest,Automatic climate con...
# 1    7.0  Air conditioning,Automatic climate control,Hil...
# 2    7.0  Air conditioning,Cruise control,Electrical sid...
# 3    6.0  Air suspension,Armrest,Auxiliary heating,Elect...
# 4    7.0  Air conditioning,Armrest,Automatic climate con...
#
#                                  Entertainment_Media  ... Previous_Owners  \
# 0  Bluetooth,Hands-free equipment,On-board comput...  ...             2.0
# 1  Bluetooth,Hands-free equipment,On-board comput...  ...             1.0
# 2                              MP3,On-board computer  ...             1.0
# 3  Bluetooth,CD player,Hands-free equipment,MP3,O...  ...             1.0
# 4  Bluetooth,CD player,Hands-free equipment,MP3,O...  ...             1.0
#
#    hp_kW  Inspection_new  Paint_Type  Upholstery_type  Gearing_Type  \
# 0   66.0               1    Metallic            Cloth     Automatic
# 1  141.0               0    Metallic            Cloth     Automatic
# 2   85.0               0    Metallic            Cloth     Automatic
# 3   66.0               0    Metallic            Cloth     Automatic
# 4   66.0               1    Metallic            Cloth     Automatic
#
#   Displacement_cc Weight_kg Drive_chain  cons_comb
# 0          1422.0    1220.0       front        3.8
# 1          1798.0    1255.0       front        5.6
# 2          1598.0    1135.0       front        3.8
# 3          1422.0    1195.0       front        3.8
# 4          1422.0    1135.0       front        4.1
#
# [5 rows x 23 columns]

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15915 entries, 0 to 15914
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make_model           15915 non-null  object
#  1   body_type            15915 non-null  object
#  2   price                15915 non-null  int64
#  3   vat                  15915 non-null  object
#  4   km                   15915 non-null  float64
#  5   Type                 15915 non-null  object
#  6   Fuel                 15915 non-null  object
#  7   Gears                15915 non-null  float64
#  8   Comfort_Convenience  15915 non-null  object
#  9   Entertainment_Media  15915 non-null  object
#  10  Extras               15915 non-null  object
#  11  Safety_Security      15915 non-null  object
#  12  age                  15915 non-null  float64
#  13  Previous_Owners      15915 non-null  float64
#  14  hp_kW                15915 non-null  float64
#  15  Inspection_new       15915 non-null  int64
#  16  Paint_Type           15915 non-null  object
#  17  Upholstery_type      15915 non-null  object
#  18  Gearing_Type         15915 non-null  object
#  19  Displacement_cc      15915 non-null  float64
#  20  Weight_kg            15915 non-null  float64
#  21  Drive_chain          15915 non-null  object
#  22  cons_comb            15915 non-null  float64
# dtypes: float64(8), int64(2), object(13)
# memory usage: 2.8+ MB

# %%
df.describe().T
# Out:
#                    count          mean           std     min      25%  \
# price            15915.0  18024.380584   7381.679318  4950.0  12850.0
# km               15915.0  32089.995708  36977.214964     0.0   1920.5
# Gears            15915.0      5.937355      0.704772     5.0      5.0
# age              15915.0      1.389695      1.121306     0.0      0.0
# Previous_Owners  15915.0      1.042853      0.339178     0.0      1.0
# hp_kW            15915.0     88.499340     26.674341    40.0     66.0
# Inspection_new   15915.0      0.247063      0.431317     0.0      0.0
# Displacement_cc  15915.0   1428.661891    275.804272   890.0   1229.0
# Weight_kg        15915.0   1337.700534    199.682385   840.0   1165.0
# cons_comb        15915.0      4.832124      0.867530     3.0      4.1
#
#                      50%      75%       max
# price            16900.0  21900.0   74600.0
# km               20413.0  46900.0  317000.0
# Gears                6.0      6.0       8.0
# age                  1.0      2.0       3.0
# Previous_Owners      1.0      1.0       4.0
# hp_kW               85.0    103.0     294.0
# Inspection_new       0.0      0.0       1.0
# Displacement_cc   1461.0   1598.0    2967.0
# Weight_kg         1295.0   1472.0    2471.0
# cons_comb            4.8      5.4       9.1

# %%
df.isnull().sum()
# Out:
# make_model             0
# body_type              0
# price                  0
# vat                    0
# km                     0
# Type                   0
# Fuel                   0
# Gears                  0
# Comfort_Convenience    0
# Entertainment_Media    0
# Extras                 0
# Safety_Security        0
# age                    0
# Previous_Owners        0
# hp_kW                  0
# Inspection_new         0
# Paint_Type             0
# Upholstery_type        0
# Gearing_Type           0
# Displacement_cc        0
# Weight_kg              0
# Drive_chain            0
# cons_comb              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1673

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
def outliers(df):
    
    numeric_df = df.select_dtypes(include='number')
    
    for col in df.select_dtypes(include='number').columns:

        Q1 = df[col].quantile(0.25)

        Q3 = df[col].quantile(0.75)

        IQR = Q3 - Q1

        outliers = numeric_df[(numeric_df[col] < (Q1 - 3 * IQR)) | (df[col] > (Q3 + 3 * IQR))]

        

        print(f"{col} - Outliers:")

        print(f"Number of Outliers: {outliers.shape[0]}")

        print(outliers[[col]])  

        print("---------------------------")

# %% [markdown]
# ### Outlier Detection and Analysis
#
# Outliers have been identified in the dataset for several variables. After a thorough review, it has been determined that these outliers represent valid and realistic data points rather than errors or anomalies caused by data entry issues.
#
# For example:
# - High values in `fuel_consumption_city` and `fuel_consumption_comb` likely correspond to vehicles with larger engines or heavy-duty use.
# - High `fuel_consumption_comb(mpg)` values may reflect highly fuel-efficient vehicles such as hybrids or electric cars.
# - The presence of vehicles with 16 cylinders is rare but plausible for specific types of high-performance or luxury vehicles.
#
# Given that these outliers are genuine data points, removing them would result in a loss of valuable information about the dataset's variability. Therefore, the outliers will be retained for the analysis, ensuring that the results remain comprehensive and inclusive of all relevant cases.

# %%
outliers(df)
# Out:
# price - Outliers:
# Number of Outliers: 57
#        price
# 3587   64900
# 3590   62900
# 3592   56900
# 3593   58500
# 3594   58990
# 3595   63900
# 3596   57400
# 3597   56100
# 3598   55000
# 3599   55000
# 3600   53000
# 3601   51900
# 3602   51900
# 3603   52000
# 3604   50000
# 3605   51999
# 3606   49900
# 3648   74600
# 3649   67600
# 12747  49884
# 12748  49350
# 12749  52120
# 12752  48950
# 15388  56950
# 15803  57990
# 15804  58950
# 15805  57800
# 15806  55800
# 15807  55285
# 15808  54982
# 15809  54500
# 15811  54925
# 15812  54205
# 15813  54204
# 15814  54120
# 15815  53935
# 15816  52990
# 15817  50950
# 15818  50950
# 15820  52711
# 15821  51750
# 15822  68320
# 15824  64332
# 15825  50170
# 15826  49900
# 15827  64298
# 15829  63477
# 15830  50750
# 15863  49490
# 15864  49690
# 15865  49100
# 15866  48990
# 15867  48990
# 15868  49390
# 15869  48900
# 15871  48800
# 15872  48765
# ---------------------------
# km - Outliers:
# Number of Outliers: 65
#              km
# 63     192000.0
# 2985   186000.0
# 2987   207000.0
# 2996   179000.0
# 3003   291800.0
# ...         ...
# 11175  214999.0
# 15273  240000.0
# 15274  180000.0
# 15279  197414.0
# 15316  197323.0
#
# [65 rows x 1 columns]
# ---------------------------
# Gears - Outliers:
# Number of Outliers: 0
# Empty DataFrame
# Columns: [Gears]
# Index: []
# ---------------------------
# age - Outliers:
# Number of Outliers: 0
# Empty DataFrame
# Columns: [age]
# Index: []
# ---------------------------
# Previous_Owners - Outliers:
# Number of Outliers: 1542
#        Previous_Owners
# 0                  2.0
# 38                 2.0
# 47                 0.0
# 48                 2.0
# 58                 2.0
# ...                ...
# 15762              2.0
# 15849              0.0
# 15850              0.0
# 15856              0.0
# 15857              0.0
#
# [1542 rows x 1 columns]
# ---------------------------
# hp_kW - Outliers:
# Number of Outliers: 23
#        hp_kW
# 3587   294.0
# 3590   294.0
# 3592   294.0
# 3593   294.0
# 3594   228.0
# 3595   294.0
# 3596   294.0
# 3597   228.0
# 3598   294.0
# 3599   294.0
# 3600   294.0
# 3601   294.0
# 3602   294.0
# 3603   294.0
# 3604   294.0
# 3605   294.0
# 3606   294.0
# 3608   270.0
# 3609   270.0
# 3610   294.0
# 3648   294.0
# 3649   294.0
# 10509  239.0
# ---------------------------
# Inspection_new - Outliers:
# Number of Outliers: 0
# Empty DataFrame
# Columns: [Inspection_new]
# Index: []
# ---------------------------
# Displacement_cc - Outliers:
# Number of Outliers: 1
#        Displacement_cc
# 10767           2967.0
# ---------------------------
# Weight_kg - Outliers:
# Number of Outliers: 4
#        Weight_kg
# 14971     2471.0
# 15181     2471.0
# 15276     2471.0
# 15674     2471.0
# ---------------------------
# cons_comb - Outliers:
# Number of Outliers: 0
# Empty DataFrame
# Columns: [cons_comb]
# Index: []
# ---------------------------

# %%
fig, axes = plt.subplots(1, 4, figsize=(18, 6))  

# Boxplotlar
sns.boxplot(x="price", data=df, color="#4A90E2", ax=axes[0], width=0.6)
sns.boxplot(x="km", data=df, color="#50C878", ax=axes[1], width=0.6)
sns.boxplot(x="Previous_Owners", data=df, color="#FFC300", ax=axes[2], width=0.6)
sns.boxplot(x="hp_kW", data=df, color="#FF5733", ax=axes[3], width=0.6)

# Başlıklar ve Etiketler
axes[0].set_title("Price Distribution", fontsize=12)
axes[0].set_xlabel("Price (in $)", fontsize=10)

axes[1].set_title("Kilometer Distribution", fontsize=12)
axes[1].set_xlabel("Kilometers Driven", fontsize=10)

axes[2].set_title("Previous Owners Distribution", fontsize=12)
axes[2].set_xlabel("Number of Owners", fontsize=10)

axes[3].set_title("Horsepower Distribution", fontsize=12)
axes[3].set_xlabel("Horsepower (kW)", fontsize=10)

# Genel Ayarlar
for ax in axes:
    ax.grid(axis='x', linestyle='--', alpha=0.7)  
    ax.tick_params(axis='x', rotation=45, labelsize=9) 
    ax.set_ylabel("")  

plt.tight_layout() 
plt.show()

# %%
plt.figure(figsize = (9,6))
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot = True, fmt=".2f",cmap="coolwarm", linecolor='black');

# %%
# sns.pairplot(df.select_dtypes(include='number'), hue="price", palette="coolwarm");

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 4))

sns.scatterplot(x="km",y="price" ,data=df ,ax=axes[0,0], color="#ff5733")

sns.regplot(x="Gears",y="price" ,data=df,  ax=axes[0,1],color="#68ff43")

sns.scatterplot(x="hp_kW",y="price" ,data=df ,ax=axes[1,0],color="#ff434c")

sns.regplot(x="age",y="price" ,data=df,  ax=axes[1,1])

plt.tight_layout()

plt.show()

# %% [markdown]
# # Train | Test Split

# %%
X = df.select_dtypes(include = "number").drop("price",axis=1)
y = df.price

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# %% [markdown]
# # Implement Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_scaled = scaler.transform(X_train)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([ 8066.73990967, 13866.28584195, 20538.99691218, ...,
#        32551.07622929, 13042.91338231, 19176.09103918])

# %%
my_dict= {"Actual": y_test , "pred":y_pred, "residual":y_test - y_pred  }
comparing = pd.DataFrame(my_dict)
comparing
# Out:
#        Actual          pred     residual
# 9393     8990   8066.739910   923.260090
# 14593   10450  13866.285842 -3416.285842
# 11516   18800  20538.996912 -1738.996912
# 13933    9200  10538.757080 -1338.757080
# 12350   19980  23813.606208 -3833.606208
# ...       ...           ...          ...
# 3096    14990  12085.384340  2904.615660
# 13739    6790   7059.801647  -269.801647
# 12555   33700  32551.076229  1148.923771
# 2924    15990  13042.913382  2947.086618
# 13081   15990  19176.091039 -3186.091039
#
# [2849 rows x 3 columns]

# %%
result_sample = comparing.head(25)

# %%
result_sample.plot(kind= "bar", figsize = (15,9))
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score

# %%
R2_score = r2_score(y_test,y_pred)
R2_score
# Out:
# 0.7598431469561479

# %%
train_predict = model.predict(X_train_scaled)
train_predict
# Out:
# array([ 9389.31715915, 23961.23252977, 21089.88779534, ...,
#        29122.62479047, 34365.8904211 , 20380.02335506])

# %%
R2_score_tr = r2_score(y_train,train_predict)
R2_score_tr
# Out:
# 0.7513887509830875

# %%
def eval_metric(actual, pred):
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    rmse = np.sqrt(mean_squared_error(actual, pred))
    R2_score = r2_score(actual, pred)
    print("Model testing performance: ")
    print("---------------------------")
    print(f"R2_score \t: {R2_score}")
    print(f"MAE \t\t: {mae}")
    print(f"MSE \t\t: {mse}")
    print(f"RMSE \t\t: {rmse}")

# %%
from sklearn.model_selection import cross_validate, cross_val_score

# %%
model = LinearRegression()

# %%
scores = cross_validate(model, X_train_scaled, y_train,
               scoring = ['r2', 'neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_root_mean_squared_error'],
               cv=10, return_train_score=True)

# %%
scores = pd.DataFrame(scores, index = range(1,11))
scores.iloc[:, 2:].mean()
# Out:
# test_r2                              7.505558e-01
# train_r2                             7.514152e-01
# test_neg_mean_absolute_error        -2.726266e+03
# train_neg_mean_absolute_error       -2.723513e+03
# test_neg_mean_squared_error         -1.355596e+07
# train_neg_mean_squared_error        -1.352422e+07
# test_neg_root_mean_squared_error    -3.678417e+03
# train_neg_root_mean_squared_error   -3.677485e+03
# dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def train_val(y_train, y_train_pred, y_test, y_pred, i): 
    
    scores = {i+"_train": {"R2" : r2_score(y_train, y_train_pred),
    "mae" : mean_absolute_error(y_train, y_train_pred),
    "mse" : mean_squared_error(y_train, y_train_pred),                          
    "rmse" : np.sqrt(mean_squared_error(y_train, y_train_pred))},
    
    i+"_test": {"R2" : r2_score(y_test, y_pred),
    "mae" : mean_absolute_error(y_test, y_pred),
    "mse" : mean_squared_error(y_test, y_pred),
    "rmse" : np.sqrt(mean_squared_error(y_test, y_pred))}}
    
    return pd.DataFrame(scores)

# %% [markdown]
# # Implement Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha=1.59)

# %%
ridge_model.fit(X_train_scaled, y_train)
# Out:
# Ridge(alpha=1.59)

# %%
y_test_pred = ridge_model.predict(X_test_scaled)
y_train_pred = ridge_model.predict(X_train_scaled)

# %%
rm = train_val(y_train, y_train_pred, y_test, y_pred, "ridge")
rm
# Out:
#        ridge_train    ridge_test
# R2    7.513887e-01  7.598431e-01
# mae   2.723625e+03  2.751779e+03
# mse   1.352581e+07  1.385460e+07
# rmse  3.677745e+03  3.722177e+03

# %%
model = Ridge(alpha=1.59)

scores = cross_validate(model, X_train_scaled, y_train, 
                        scoring = ['r2', 'neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_root_mean_squared_error'],
                       cv=10, return_train_score=True)
scores
# Out:
# {'fit_time': array([0.00312352, 0.        , 0.        , 0.00939465, 0.        ,
#         0.00795078, 0.        , 0.        , 0.00179076, 0.00934935]),
#  'score_time': array([0.00917721, 0.01092958, 0.00999641, 0.        , 0.00803614,
#         0.        , 0.00795293, 0.01044846, 0.00322342, 0.        ]),
#  'test_r2': array([0.74972379, 0.71941366, 0.7656936 , 0.73096605, 0.76522639,
#         0.74345624, 0.73976747, 0.76961828, 0.75698895, 0.76470891]),
#  'train_r2': array([0.75156505, 0.75444431, 0.74973441, 0.75379752, 0.74982468,
#         0.75220769, 0.75262161, 0.74945006, 0.75076024, 0.74974569]),
#  'test_neg_mean_absolute_error': array([-2742.48987694, -2725.80512849, -2700.96183997, -2803.54408646,
#         -2653.49732448, -2724.29452242, -2791.51315938, -2651.05887793,
#         -2706.34113642, -2763.29211488]),
#  'train_neg_mean_absolute_error': array([-2717.78463337, -2726.88618188, -2728.76348309, -2708.60876773,
#         -2731.43011432, -2726.37443845, -2716.23603269, -2736.99911738,
#         -2724.73825823, -2717.49863352]),
#  'test_neg_mean_squared_error': array([-14199754.73559209, -13496375.35193722, -12970490.10396031,
#         -16305726.0034308 , -12680201.62444489, -13298927.81625576,
#         -14406811.59623889, -11627909.46860617, -12887911.2961264 ,
#         -13685443.37328577]),
#  'train_neg_mean_squared_error': array([-13451747.38994896, -13531704.99321239, -13588960.40710005,
#         -13221018.87894789, -13621129.91641957, -13551895.19669474,
#         -13429492.46440526, -13739620.32907215, -13597646.92905995,
#         -13508992.11462594]),
#  'test_neg_root_mean_squared_error': array([-3768.25619293, -3673.74132894, -3601.45666418, -4038.03491855,
#         -3560.92707373, -3646.76950413, -3795.6305927 , -3409.97206273,
#         -3589.97371803, -3699.38418839]),
#  'train_neg_root_mean_squared_error': array([-3667.66238767, -3678.54658707, -3686.32071409, -3636.07190233,
#         -3690.68149756, -3681.28988219, -3664.6271931 , -3706.69938477,
#         -3687.49873614, -3675.45808228])}

# %%
pd.DataFrame(scores, index= range(1,11))
# Out:
#     fit_time  score_time   test_r2  train_r2  test_neg_mean_absolute_error  \
# 1   0.003124    0.009177  0.749724  0.751565                  -2742.489877
# 2   0.000000    0.010930  0.719414  0.754444                  -2725.805128
# 3   0.000000    0.009996  0.765694  0.749734                  -2700.961840
# 4   0.009395    0.000000  0.730966  0.753798                  -2803.544086
# 5   0.000000    0.008036  0.765226  0.749825                  -2653.497324
# 6   0.007951    0.000000  0.743456  0.752208                  -2724.294522
# 7   0.000000    0.007953  0.739767  0.752622                  -2791.513159
# 8   0.000000    0.010448  0.769618  0.749450                  -2651.058878
# 9   0.001791    0.003223  0.756989  0.750760                  -2706.341136
# 10  0.009349    0.000000  0.764709  0.749746                  -2763.292115
#
#     train_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 1                    -2717.784633                -1.419975e+07
# 2                    -2726.886182                -1.349638e+07
# 3                    -2728.763483                -1.297049e+07
# 4                    -2708.608768                -1.630573e+07
# 5                    -2731.430114                -1.268020e+07
# 6                    -2726.374438                -1.329893e+07
# 7                    -2716.236033                -1.440681e+07
# 8                    -2736.999117                -1.162791e+07
# 9                    -2724.738258                -1.288791e+07
# 10                   -2717.498634                -1.368544e+07
#
#     train_neg_mean_squared_error  test_neg_root_mean_squared_error  \
# 1                  -1.345175e+07                      -3768.256193
# 2                  -1.353170e+07                      -3673.741329
# 3                  -1.358896e+07                      -3601.456664
# 4                  -1.322102e+07                      -4038.034919
# 5                  -1.362113e+07                      -3560.927074
# 6                  -1.355190e+07                      -3646.769504
# 7                  -1.342949e+07                      -3795.630593
# 8                  -1.373962e+07                      -3409.972063
# 9                  -1.359765e+07                      -3589.973718
# 10                 -1.350899e+07                      -3699.384188
#
#     train_neg_root_mean_squared_error
# 1                        -3667.662388
# 2                        -3678.546587
# 3                        -3686.320714
# 4                        -3636.071902
# 5                        -3690.681498
# 6                        -3681.289882
# 7                        -3664.627193
# 8                        -3706.699385
# 9                        -3687.498736
# 10                       -3675.458082

# %%
scores = pd.DataFrame(scores, index= range(1,11))
scores.iloc[:, 2:].mean()
# Out:
# test_r2                              7.505563e-01
# train_r2                             7.514151e-01
# test_neg_mean_absolute_error        -2.726280e+03
# train_neg_mean_absolute_error       -2.723532e+03
# test_neg_mean_squared_error         -1.355596e+07
# train_neg_mean_squared_error        -1.352422e+07
# test_neg_root_mean_squared_error    -3.678415e+03
# train_neg_root_mean_squared_error   -3.677486e+03
# dtype: float64

# %%
from sklearn.model_selection import GridSearchCV

# %%
alpha_space = np.linspace(1, 5, 100)
alpha_space
# Out:
# array([1.        , 1.04040404, 1.08080808, 1.12121212, 1.16161616,
#        1.2020202 , 1.24242424, 1.28282828, 1.32323232, 1.36363636,
#        1.4040404 , 1.44444444, 1.48484848, 1.52525253, 1.56565657,
#        1.60606061, 1.64646465, 1.68686869, 1.72727273, 1.76767677,
#        1.80808081, 1.84848485, 1.88888889, 1.92929293, 1.96969697,
#        2.01010101, 2.05050505, 2.09090909, 2.13131313, 2.17171717,
#        2.21212121, 2.25252525, 2.29292929, 2.33333333, 2.37373737,
#        2.41414141, 2.45454545, 2.49494949, 2.53535354, 2.57575758,
#        2.61616162, 2.65656566, 2.6969697 , 2.73737374, 2.77777778,
#        2.81818182, 2.85858586, 2.8989899 , 2.93939394, 2.97979798,
#        3.02020202, 3.06060606, 3.1010101 , 3.14141414, 3.18181818,
#        3.22222222, 3.26262626, 3.3030303 , 3.34343434, 3.38383838,
#        3.42424242, 3.46464646, 3.50505051, 3.54545455, 3.58585859,
#        3.62626263, 3.66666667, 3.70707071, 3.74747475, 3.78787879,
#        3.82828283, 3.86868687, 3.90909091, 3.94949495, 3.98989899,
#        4.03030303, 4.07070707, 4.11111111, 4.15151515, 4.19191919,
#        4.23232323, 4.27272727, 4.31313131, 4.35353535, 4.39393939,
#        4.43434343, 4.47474747, 4.51515152, 4.55555556, 4.5959596 ,
#        4.63636364, 4.67676768, 4.71717172, 4.75757576, 4.7979798 ,
#        4.83838384, 4.87878788, 4.91919192, 4.95959596, 5.        ])

# %%
param_grid = {"alpha" : alpha_space}

# %%
ridge_model = Ridge()

# %%
grid_ridge = GridSearchCV(estimator = ridge_model, param_grid= param_grid, scoring= "neg_root_mean_squared_error", 
                         cv=10,  verbose=3, return_train_score=True)

# %%
grid_ridge.fit(X_train_scaled, y_train)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# [CV 1/10] END alpha=1.0;, score=(train=-3667.662, test=-3768.251) total time=   0.0s
# [CV 2/10] END alpha=1.0;, score=(train=-3678.546, test=-3673.769) total time=   0.0s
# [CV 3/10] END alpha=1.0;, score=(train=-3686.321, test=-3601.456) total time=   0.0s
# [CV 4/10] END alpha=1.0;, score=(train=-3636.072, test=-4037.999) total time=   0.0s
# [CV 5/10] END alpha=1.0;, score=(train=-3690.681, test=-3560.930) total time=   0.0s
# [CV 6/10] END alpha=1.0;, score=(train=-3681.290, test=-3646.765) total time=   0.0s
# [CV 7/10] END alpha=1.0;, score=(train=-3664.627, test=-3795.624) total time=   0.0s
# [CV 8/10] END alpha=1.0;, score=(train=-3706.699, test=-3410.002) total time=   0.0s
# [CV 9/10] END alpha=1.0;, score=(train=-3687.499, test=-3589.994) total time=   0.0s
# [CV 10/10] END alpha=1.0;, score=(train=-3675.458, test=-3699.367) total time=   0.0s
# [CV 1/10] END alpha=1.0404040404040404;, score=(train=-3667.662, test=-3768.251) total time=   0.0s
# [CV 2/10] END alpha=1.0404040404040404;, score=(train=-3678.546, test=-3673.768) total time=   0.0s
# [CV 3/10] END alpha=1.0404040404040404;, score=(train=-3686.321, test=-3601.456) total time=   0.0s
# [CV 4/10] END alpha=1.0404040404040404;, score=(train=-3636.072, test=-4038.001) total time=   0.0s
# [CV 5/10] END alpha=1.0404040404040404;, score=(train=-3690.681, test=-3560.929) total time=   0.0s
# [CV 6/10] END alpha=1.0404040404040404;, score=(train=-3681.290, test=-3646.765) total time=   0.0s
# [CV 7/10] END alpha=1.0404040404040404;, score=(train=-3664.627, test=-3795.625) total time=   0.0s
# [CV 8/10] END alpha=1.0404040404040404;, score=(train=-3706.699, test=-3410.000) total time=   0.0s
# [CV 9/10] END alpha=1.0404040404040404;, score=(train=-3687.499, test=-3589.993) total time=   0.0s
# [CV 10/10] END alpha=1.0404040404040404;, score=(train=-3675.458, test=-3699.368) total time=   0.0s
# [CV 1/10] END alpha=1.0808080808080809;, score=(train=-3667.662, test=-3768.251) total time=   0.0s
# [CV 2/10] END alpha=1.0808080808080809;, score=(train=-3678.546, test=-3673.766) total time=   0.0s
# [CV 3/10] END alpha=1.0808080808080809;, score=(train=-3686.321, test=-3601.456) total time=   0.0s
# [CV 4/10] END alpha=1.0808080808080809;, score=(train=-3636.072, test=-4038.004) total time=   0.0s
# [CV 5/10] END alpha=1.0808080808080809;, score=(train=-3690.681, test=-3560.929) total time=   0.0s
# [CV 6/10] END alpha=1.0808080808080809;, score=(train=-3681.290, test=-3646.765) total time=   0.0s
# [CV 7/10] END alpha=1.0808080808080809;, score=(train=-3664.627, test=-3795.625) total time=   0.0s
# [CV 8/10] END alpha=1.0808080808080809;, score=(train=-3706.699, test=-3409.998) total time=   0.0s
# [CV 9/10] END alpha=1.0808080808080809;, score=(train=-3687.499, test=-3589.991) total time=   0.0s
# [CV 10/10] END alpha=1.0808080808080809;, score=(train=-3675.458, test=-3699.370) total time=   0.0s
# [CV 1/10] END alpha=1.121212121212121;, score=(train=-3667.662, test=-3768.252) total time=   0.0s
# [CV 2/10] END alpha=1.121212121212121;, score=(train=-3678.546, test=-3673.764) total time=   0.0s
# [CV 3/10] END alpha=1.121212121212121;, score=(train=-3686.321, test=-3601.456) total time=   0.0s
# [CV 4/10] END alpha=1.121212121212121;, score=(train=-3636.072, test=-4038.006) total time=   0.0s
# [CV 5/10] END alpha=1.121212121212121;, score=(train=-3690.681, test=-3560.929) total time=   0.0s
# [CV 6/10] END alpha=1.121212121212121;, score=(train=-3681.290, test=-3646.766) total time=   0.0s
# [CV 7/10] END alpha=1.121212121212121;, score=(train=-3664.627, test=-3795.625) total time=   0.0s
# [CV 8/10] END alpha=1.121212121212121;, score=(train=-3706.699, test=-3409.996) total time=   0.0s
# [CV 9/10] END alpha=1.121212121212121;, score=(train=-3687.499, test=-3589.990) total time=   0.0s
# [CV 10/10] END alpha=1.121212121212121;, score=(train=-3675.458, test=-3699.371) total time=   0.0s
# [CV 1/10] END alpha=1.1616161616161615;, score=(train=-3667.662, test=-3768.252) total time=   0.0s
# [CV 2/10] END alpha=1.1616161616161615;, score=(train=-3678.546, test=-3673.762) total time=   0.0s
# [CV 3/10] END alpha=1.1616161616161615;, score=(train=-3686.321, test=-3601.456) total time=   0.0s
# [CV 4/10] END alpha=1.1616161616161615;, score=(train=-3636.072, test=-4038.008) total time=   0.0s
# [CV 5/10] END alpha=1.1616161616161615;, score=(train=-3690.681, test=-3560.929) total time=   0.0s
# [CV 6/10] END alpha=1.1616161616161615;, score=(train=-3681.290, test=-3646.766) total time=   0.0s
# [CV 7/10] END alpha=1.1616161616161615;, score=(train=-3664.627, test=-3795.626) total time=   0.0s
# [CV 8/10] END alpha=1.1616161616161615;, score=(train=-3706.699, test=-3409.994) total time=   0.0s
# [CV 9/10] END alpha=1.1616161616161615;, score=(train=-3687.499, test=-3589.988) total time=   0.0s
# [CV 10/10] END alpha=1.1616161616161615;, score=(train=-3675.458, test=-3699.372) total time=   0.0s
# [CV 1/10] END alpha=1.202020202020202;, score=(train=-3667.662, test=-3768.252) total time=   0.0s
# [CV 2/10] END alpha=1.202020202020202;, score=(train=-3678.546, test=-3673.760) total time=   0.0s
# [CV 3/10] END alpha=1.202020202020202;, score=(train=-3686.321, test=-3601.456) total time=   0.0s
# [CV 4/10] END alpha=1.202020202020202;, score=(train=-3636.072, test=-4038.011) total time=   0.0s
# [CV 5/10] END alpha=1.202020202020202;, score=(train=-3690.681, test=-3560.929) total time=   0.0s
# [CV 6/10] END alpha=1.202020202020202;, score=(train=-3681.290, test=-3646.766) total time=   0.0s
# [CV 7/10] END alpha=1.202020202020202;, score=(train=-3664.627, test=-3795.626) total time=   0.0s
# [CV 8/10] END alpha=1.202020202020202;, score=(train=-3706.699, test=-3409.992) total time=   0.0s
# [CV 9/10] END alpha=1.202020202020202;, score=(train=-3687.499, test=-3589.987) total time=   0.0s
# [CV 10/10] END alpha=1.202020202020202;, score=(train=-3675.458, test=-3699.373) total time=   0.0s
# [CV 1/10] END alpha=1.2424242424242424;, score=(train=-3667.662, test=-3768.253) total time=   0.0s
# [CV 2/10] END alpha=1.2424242424242424;, score=(train=-3678.547, test=-3673.758) total time=   0.0s
# [CV 3/10] END alpha=1.2424242424242424;, score=(train=-3686.321, test=-3601.456) total time=   0.0s
# [CV 4/10] END alpha=1.2424242424242424;, score=(train=-3636.072, test=-4038.013) total time=   0.0s
# [CV 5/10] END alpha=1.2424242424242424;, score=(train=-3690.681, test=-3560.929) total time=   0.0s
# [CV 6/10] END alpha=1.2424242424242424;, score=(train=-3681.290, test=-3646.767) total time=   0.0s
# [CV 7/10] END alpha=1.2424242424242424;, score=(train=-3664.627, test=-3795.627) total time=   0.0s
# [CV 8/10] END alpha=1.2424242424242424;, score=(train=-3706.699, test=-3409.990) total time=   0.0s
# [CV 9/10] END alpha=1.2424242424242424;, score=(train=-3687.499, test=-3589.986) total time=   0.0s
# [CV 10/10] END alpha=1.2424242424242424;, score=(train=-3675.458, test=-3699.374) total time=   0.0s
# [CV 1/10] END alpha=1.2828282828282829;, score=(train=-3667.662, test=-3768.253) total time=   0.0s
# [CV 2/10] END alpha=1.2828282828282829;, score=(train=-3678.547, test=-3673.756) total time=   0.0s
# [CV 3/10] END alpha=1.2828282828282829;, score=(train=-3686.321, test=-3601.456) total time=   0.0s
# [CV 4/10] END alpha=1.2828282828282829;, score=(train=-3636.072, test=-4038.016) total time=   0.0s
# [CV 5/10] END alpha=1.2828282828282829;, score=(train=-3690.681, test=-3560.928) total time=   0.0s
# [CV 6/10] END alpha=1.2828282828282829;, score=(train=-3681.290, test=-3646.767) total time=   0.0s
# [CV 7/10] END alpha=1.2828282828282829;, score=(train=-3664.627, test=-3795.627) total time=   0.0s
# [CV 8/10] END alpha=1.2828282828282829;, score=(train=-3706.699, test=-3409.988) total time=   0.0s
# [CV 9/10] END alpha=1.2828282828282829;, score=(train=-3687.499, test=-3589.984) total time=   0.0s
# [CV 10/10] END alpha=1.2828282828282829;, score=(train=-3675.458, test=-3699.375) total time=   0.0s
# [CV 1/10] END alpha=1.3232323232323233;, score=(train=-3667.662, test=-3768.254) total time=   0.0s
# [CV 2/10] END alpha=1.3232323232323233;, score=(train=-3678.547, test=-3673.754) total time=   0.0s
# [CV 3/10] END alpha=1.3232323232323233;, score=(train=-3686.321, test=-3601.456) total time=   0.0s
# [CV 4/10] END alpha=1.3232323232323233;, score=(train=-3636.072, test=-4038.018) total time=   0.0s
# [CV 5/10] END alpha=1.3232323232323233;, score=(train=-3690.681, test=-3560.928) total time=   0.0s
# [CV 6/10] END alpha=1.3232323232323233;, score=(train=-3681.290, test=-3646.767) total time=   0.0s
# [CV 7/10] END alpha=1.3232323232323233;, score=(train=-3664.627, test=-3795.628) total time=   0.0s
# [CV 8/10] END alpha=1.3232323232323233;, score=(train=-3706.699, test=-3409.986) total time=   0.0s
# [CV 9/10] END alpha=1.3232323232323233;, score=(train=-3687.499, test=-3589.983) total time=   0.0s
# [CV 10/10] END alpha=1.3232323232323233;, score=(train=-3675.458, test=-3699.376) total time=   0.0s
# [CV 1/10] END alpha=1.3636363636363638;, score=(train=-3667.662, test=-3768.254) total time=   0.0s
# [CV 2/10] END alpha=1.3636363636363638;, score=(train=-3678.547, test=-3673.752) total time=   0.0s
# [CV 3/10] END alpha=1.3636363636363638;, score=(train=-3686.321, test=-3601.456) total time=   0.0s
# [CV 4/10] END alpha=1.3636363636363638;, score=(train=-3636.072, test=-4038.021) total time=   0.0s
# [CV 5/10] END alpha=1.3636363636363638;, score=(train=-3690.681, test=-3560.928) total time=   0.0s
# [CV 6/10] END alpha=1.3636363636363638;, score=(train=-3681.290, test=-3646.768) total time=   0.0s
# [CV 7/10] END alpha=1.3636363636363638;, score=(train=-3664.627, test=-3795.628) total time=   0.0s
# [CV 8/10] END alpha=1.3636363636363638;, score=(train=-3706.699, test=-3409.984) total time=   0.0s
# [CV 9/10] END alpha=1.3636363636363638;, score=(train=-3687.499, test=-3589.981) total time=   0.0s
# [CV 10/10] END alpha=1.3636363636363638;, score=(train=-3675.458, test=-3699.378) total time=   0.0s
# [CV 1/10] END alpha=1.404040404040404;, score=(train=-3667.662, test=-3768.254) total time=   0.0s
# [CV 2/10] END alpha=1.404040404040404;, score=(train=-3678.547, test=-3673.750) total time=   0.0s
# [CV 3/10] END alpha=1.404040404040404;, score=(train=-3686.321, test=-3601.456) total time=   0.0s
# [CV 4/10] END alpha=1.404040404040404;, score=(train=-3636.072, test=-4038.023) total time=   0.0s
# [CV 5/10] END alpha=1.404040404040404;, score=(train=-3690.681, test=-3560.928) total time=   0.0s
# [CV 6/10] END alpha=1.404040404040404;, score=(train=-3681.290, test=-3646.768) total time=   0.0s
# [CV 7/10] END alpha=1.404040404040404;, score=(train=-3664.627, test=-3795.629) total time=   0.0s
# [CV 8/10] END alpha=1.404040404040404;, score=(train=-3706.699, test=-3409.982) total time=   0.0s
# [CV 9/10] END alpha=1.404040404040404;, score=(train=-3687.499, test=-3589.980) total time=   0.0s
# [CV 10/10] END alpha=1.404040404040404;, score=(train=-3675.458, test=-3699.379) total time=   0.0s
# [CV 1/10] END alpha=1.4444444444444444;, score=(train=-3667.662, test=-3768.255) total time=   0.0s
# [CV 2/10] END alpha=1.4444444444444444;, score=(train=-3678.547, test=-3673.748) total time=   0.0s
# [CV 3/10] END alpha=1.4444444444444444;, score=(train=-3686.321, test=-3601.456) total time=   0.0s
# [CV 4/10] END alpha=1.4444444444444444;, score=(train=-3636.072, test=-4038.026) total time=   0.0s
# [CV 5/10] END alpha=1.4444444444444444;, score=(train=-3690.681, test=-3560.928) total time=   0.0s
# [CV 6/10] END alpha=1.4444444444444444;, score=(train=-3681.290, test=-3646.768) total time=   0.0s
# [CV 7/10] END alpha=1.4444444444444444;, score=(train=-3664.627, test=-3795.629) total time=   0.0s
# [CV 8/10] END alpha=1.4444444444444444;, score=(train=-3706.699, test=-3409.980) total time=   0.0s
# [CV 9/10] END alpha=1.4444444444444444;, score=(train=-3687.499, test=-3589.979) total time=   0.0s
# [CV 10/10] END alpha=1.4444444444444444;, score=(train=-3675.458, test=-3699.380) total time=   0.0s
# [CV 1/10] END alpha=1.4848484848484849;, score=(train=-3667.662, test=-3768.255) total time=   0.0s
# [CV 2/10] END alpha=1.4848484848484849;, score=(train=-3678.547, test=-3673.746) total time=   0.0s
# [CV 3/10] END alpha=1.4848484848484849;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=1.4848484848484849;, score=(train=-3636.072, test=-4038.028) total time=   0.0s
# [CV 5/10] END alpha=1.4848484848484849;, score=(train=-3690.681, test=-3560.928) total time=   0.0s
# [CV 6/10] END alpha=1.4848484848484849;, score=(train=-3681.290, test=-3646.769) total time=   0.0s
# [CV 7/10] END alpha=1.4848484848484849;, score=(train=-3664.627, test=-3795.629) total time=   0.0s
# [CV 8/10] END alpha=1.4848484848484849;, score=(train=-3706.699, test=-3409.977) total time=   0.0s
# [CV 9/10] END alpha=1.4848484848484849;, score=(train=-3687.499, test=-3589.977) total time=   0.0s
# [CV 10/10] END alpha=1.4848484848484849;, score=(train=-3675.458, test=-3699.381) total time=   0.0s
# [CV 1/10] END alpha=1.5252525252525253;, score=(train=-3667.662, test=-3768.256) total time=   0.0s
# [CV 2/10] END alpha=1.5252525252525253;, score=(train=-3678.547, test=-3673.744) total time=   0.0s
# [CV 3/10] END alpha=1.5252525252525253;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=1.5252525252525253;, score=(train=-3636.072, test=-4038.031) total time=   0.0s
# [CV 5/10] END alpha=1.5252525252525253;, score=(train=-3690.681, test=-3560.927) total time=   0.0s
# [CV 6/10] END alpha=1.5252525252525253;, score=(train=-3681.290, test=-3646.769) total time=   0.0s
# [CV 7/10] END alpha=1.5252525252525253;, score=(train=-3664.627, test=-3795.630) total time=   0.0s
# [CV 8/10] END alpha=1.5252525252525253;, score=(train=-3706.699, test=-3409.975) total time=   0.0s
# [CV 9/10] END alpha=1.5252525252525253;, score=(train=-3687.499, test=-3589.976) total time=   0.0s
# [CV 10/10] END alpha=1.5252525252525253;, score=(train=-3675.458, test=-3699.382) total time=   0.0s
# [CV 1/10] END alpha=1.5656565656565657;, score=(train=-3667.662, test=-3768.256) total time=   0.0s
# [CV 2/10] END alpha=1.5656565656565657;, score=(train=-3678.547, test=-3673.742) total time=   0.0s
# [CV 3/10] END alpha=1.5656565656565657;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=1.5656565656565657;, score=(train=-3636.072, test=-4038.033) total time=   0.0s
# [CV 5/10] END alpha=1.5656565656565657;, score=(train=-3690.681, test=-3560.927) total time=   0.0s
# [CV 6/10] END alpha=1.5656565656565657;, score=(train=-3681.290, test=-3646.769) total time=   0.0s
# [CV 7/10] END alpha=1.5656565656565657;, score=(train=-3664.627, test=-3795.630) total time=   0.0s
# [CV 8/10] END alpha=1.5656565656565657;, score=(train=-3706.699, test=-3409.973) total time=   0.0s
# [CV 9/10] END alpha=1.5656565656565657;, score=(train=-3687.499, test=-3589.975) total time=   0.0s
# [CV 10/10] END alpha=1.5656565656565657;, score=(train=-3675.458, test=-3699.383) total time=   0.0s
# [CV 1/10] END alpha=1.606060606060606;, score=(train=-3667.662, test=-3768.256) total time=   0.0s
# [CV 2/10] END alpha=1.606060606060606;, score=(train=-3678.547, test=-3673.741) total time=   0.0s
# [CV 3/10] END alpha=1.606060606060606;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=1.606060606060606;, score=(train=-3636.072, test=-4038.036) total time=   0.0s
# [CV 5/10] END alpha=1.606060606060606;, score=(train=-3690.682, test=-3560.927) total time=   0.0s
# [CV 6/10] END alpha=1.606060606060606;, score=(train=-3681.290, test=-3646.770) total time=   0.0s
# [CV 7/10] END alpha=1.606060606060606;, score=(train=-3664.627, test=-3795.631) total time=   0.0s
# [CV 8/10] END alpha=1.606060606060606;, score=(train=-3706.699, test=-3409.971) total time=   0.0s
# [CV 9/10] END alpha=1.606060606060606;, score=(train=-3687.499, test=-3589.973) total time=   0.0s
# [CV 10/10] END alpha=1.606060606060606;, score=(train=-3675.458, test=-3699.385) total time=   0.0s
# [CV 1/10] END alpha=1.6464646464646466;, score=(train=-3667.662, test=-3768.257) total time=   0.0s
# [CV 2/10] END alpha=1.6464646464646466;, score=(train=-3678.547, test=-3673.739) total time=   0.0s
# [CV 3/10] END alpha=1.6464646464646466;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=1.6464646464646466;, score=(train=-3636.072, test=-4038.038) total time=   0.0s
# [CV 5/10] END alpha=1.6464646464646466;, score=(train=-3690.682, test=-3560.927) total time=   0.0s
# [CV 6/10] END alpha=1.6464646464646466;, score=(train=-3681.290, test=-3646.770) total time=   0.0s
# [CV 7/10] END alpha=1.6464646464646466;, score=(train=-3664.627, test=-3795.631) total time=   0.0s
# [CV 8/10] END alpha=1.6464646464646466;, score=(train=-3706.699, test=-3409.969) total time=   0.0s
# [CV 9/10] END alpha=1.6464646464646466;, score=(train=-3687.499, test=-3589.972) total time=   0.0s
# [CV 10/10] END alpha=1.6464646464646466;, score=(train=-3675.458, test=-3699.386) total time=   0.0s
# [CV 1/10] END alpha=1.6868686868686869;, score=(train=-3667.662, test=-3768.257) total time=   0.0s
# [CV 2/10] END alpha=1.6868686868686869;, score=(train=-3678.547, test=-3673.737) total time=   0.0s
# [CV 3/10] END alpha=1.6868686868686869;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=1.6868686868686869;, score=(train=-3636.072, test=-4038.041) total time=   0.0s
# [CV 5/10] END alpha=1.6868686868686869;, score=(train=-3690.682, test=-3560.927) total time=   0.0s
# [CV 6/10] END alpha=1.6868686868686869;, score=(train=-3681.290, test=-3646.770) total time=   0.0s
# [CV 7/10] END alpha=1.6868686868686869;, score=(train=-3664.627, test=-3795.632) total time=   0.0s
# [CV 8/10] END alpha=1.6868686868686869;, score=(train=-3706.699, test=-3409.967) total time=   0.0s
# [CV 9/10] END alpha=1.6868686868686869;, score=(train=-3687.499, test=-3589.970) total time=   0.0s
# [CV 10/10] END alpha=1.6868686868686869;, score=(train=-3675.458, test=-3699.387) total time=   0.0s
# [CV 1/10] END alpha=1.7272727272727273;, score=(train=-3667.662, test=-3768.258) total time=   0.0s
# [CV 2/10] END alpha=1.7272727272727273;, score=(train=-3678.547, test=-3673.735) total time=   0.0s
# [CV 3/10] END alpha=1.7272727272727273;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=1.7272727272727273;, score=(train=-3636.072, test=-4038.043) total time=   0.0s
# [CV 5/10] END alpha=1.7272727272727273;, score=(train=-3690.682, test=-3560.926) total time=   0.0s
# [CV 6/10] END alpha=1.7272727272727273;, score=(train=-3681.290, test=-3646.771) total time=   0.0s
# [CV 7/10] END alpha=1.7272727272727273;, score=(train=-3664.627, test=-3795.632) total time=   0.0s
# [CV 8/10] END alpha=1.7272727272727273;, score=(train=-3706.699, test=-3409.965) total time=   0.0s
# [CV 9/10] END alpha=1.7272727272727273;, score=(train=-3687.499, test=-3589.969) total time=   0.0s
# [CV 10/10] END alpha=1.7272727272727273;, score=(train=-3675.458, test=-3699.388) total time=   0.0s
# [CV 1/10] END alpha=1.7676767676767677;, score=(train=-3667.662, test=-3768.258) total time=   0.0s
# [CV 2/10] END alpha=1.7676767676767677;, score=(train=-3678.547, test=-3673.733) total time=   0.0s
# [CV 3/10] END alpha=1.7676767676767677;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=1.7676767676767677;, score=(train=-3636.072, test=-4038.046) total time=   0.0s
# [CV 5/10] END alpha=1.7676767676767677;, score=(train=-3690.682, test=-3560.926) total time=   0.0s
# [CV 6/10] END alpha=1.7676767676767677;, score=(train=-3681.290, test=-3646.771) total time=   0.0s
# [CV 7/10] END alpha=1.7676767676767677;, score=(train=-3664.627, test=-3795.633) total time=   0.0s
# [CV 8/10] END alpha=1.7676767676767677;, score=(train=-3706.699, test=-3409.963) total time=   0.0s
# [CV 9/10] END alpha=1.7676767676767677;, score=(train=-3687.499, test=-3589.968) total time=   0.0s
# [CV 10/10] END alpha=1.7676767676767677;, score=(train=-3675.458, test=-3699.389) total time=   0.0s
# [CV 1/10] END alpha=1.8080808080808082;, score=(train=-3667.662, test=-3768.258) total time=   0.0s
# [CV 2/10] END alpha=1.8080808080808082;, score=(train=-3678.547, test=-3673.731) total time=   0.0s
# [CV 3/10] END alpha=1.8080808080808082;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=1.8080808080808082;, score=(train=-3636.072, test=-4038.048) total time=   0.0s
# [CV 5/10] END alpha=1.8080808080808082;, score=(train=-3690.682, test=-3560.926) total time=   0.0s
# [CV 6/10] END alpha=1.8080808080808082;, score=(train=-3681.290, test=-3646.771) total time=   0.0s
# [CV 7/10] END alpha=1.8080808080808082;, score=(train=-3664.627, test=-3795.633) total time=   0.0s
# [CV 8/10] END alpha=1.8080808080808082;, score=(train=-3706.699, test=-3409.961) total time=   0.0s
# [CV 9/10] END alpha=1.8080808080808082;, score=(train=-3687.499, test=-3589.966) total time=   0.0s
# [CV 10/10] END alpha=1.8080808080808082;, score=(train=-3675.458, test=-3699.390) total time=   0.0s
# [CV 1/10] END alpha=1.8484848484848486;, score=(train=-3667.662, test=-3768.259) total time=   0.0s
# [CV 2/10] END alpha=1.8484848484848486;, score=(train=-3678.547, test=-3673.729) total time=   0.0s
# [CV 3/10] END alpha=1.8484848484848486;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=1.8484848484848486;, score=(train=-3636.072, test=-4038.051) total time=   0.0s
# [CV 5/10] END alpha=1.8484848484848486;, score=(train=-3690.682, test=-3560.926) total time=   0.0s
# [CV 6/10] END alpha=1.8484848484848486;, score=(train=-3681.290, test=-3646.772) total time=   0.0s
# [CV 7/10] END alpha=1.8484848484848486;, score=(train=-3664.627, test=-3795.633) total time=   0.0s
# [CV 8/10] END alpha=1.8484848484848486;, score=(train=-3706.699, test=-3409.959) total time=   0.0s
# [CV 9/10] END alpha=1.8484848484848486;, score=(train=-3687.499, test=-3589.965) total time=   0.0s
# [CV 10/10] END alpha=1.8484848484848486;, score=(train=-3675.458, test=-3699.392) total time=   0.0s
# [CV 1/10] END alpha=1.8888888888888888;, score=(train=-3667.662, test=-3768.259) total time=   0.0s
# [CV 2/10] END alpha=1.8888888888888888;, score=(train=-3678.547, test=-3673.727) total time=   0.0s
# [CV 3/10] END alpha=1.8888888888888888;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=1.8888888888888888;, score=(train=-3636.072, test=-4038.053) total time=   0.0s
# [CV 5/10] END alpha=1.8888888888888888;, score=(train=-3690.682, test=-3560.926) total time=   0.0s
# [CV 6/10] END alpha=1.8888888888888888;, score=(train=-3681.290, test=-3646.772) total time=   0.0s
# [CV 7/10] END alpha=1.8888888888888888;, score=(train=-3664.627, test=-3795.634) total time=   0.0s
# [CV 8/10] END alpha=1.8888888888888888;, score=(train=-3706.699, test=-3409.957) total time=   0.0s
# [CV 9/10] END alpha=1.8888888888888888;, score=(train=-3687.499, test=-3589.963) total time=   0.0s
# [CV 10/10] END alpha=1.8888888888888888;, score=(train=-3675.458, test=-3699.393) total time=   0.0s
# [CV 1/10] END alpha=1.9292929292929295;, score=(train=-3667.662, test=-3768.259) total time=   0.0s
# [CV 2/10] END alpha=1.9292929292929295;, score=(train=-3678.547, test=-3673.725) total time=   0.0s
# [CV 3/10] END alpha=1.9292929292929295;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=1.9292929292929295;, score=(train=-3636.072, test=-4038.056) total time=   0.0s
# [CV 5/10] END alpha=1.9292929292929295;, score=(train=-3690.682, test=-3560.926) total time=   0.0s
# [CV 6/10] END alpha=1.9292929292929295;, score=(train=-3681.290, test=-3646.772) total time=   0.0s
# [CV 7/10] END alpha=1.9292929292929295;, score=(train=-3664.627, test=-3795.634) total time=   0.0s
# [CV 8/10] END alpha=1.9292929292929295;, score=(train=-3706.699, test=-3409.955) total time=   0.0s
# [CV 9/10] END alpha=1.9292929292929295;, score=(train=-3687.499, test=-3589.962) total time=   0.0s
# [CV 10/10] END alpha=1.9292929292929295;, score=(train=-3675.458, test=-3699.394) total time=   0.0s
# [CV 1/10] END alpha=1.9696969696969697;, score=(train=-3667.663, test=-3768.260) total time=   0.0s
# [CV 2/10] END alpha=1.9696969696969697;, score=(train=-3678.547, test=-3673.723) total time=   0.0s
# [CV 3/10] END alpha=1.9696969696969697;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=1.9696969696969697;, score=(train=-3636.072, test=-4038.058) total time=   0.0s
# [CV 5/10] END alpha=1.9696969696969697;, score=(train=-3690.682, test=-3560.925) total time=   0.0s
# [CV 6/10] END alpha=1.9696969696969697;, score=(train=-3681.290, test=-3646.773) total time=   0.0s
# [CV 7/10] END alpha=1.9696969696969697;, score=(train=-3664.627, test=-3795.635) total time=   0.0s
# [CV 8/10] END alpha=1.9696969696969697;, score=(train=-3706.699, test=-3409.953) total time=   0.0s
# [CV 9/10] END alpha=1.9696969696969697;, score=(train=-3687.499, test=-3589.961) total time=   0.0s
# [CV 10/10] END alpha=1.9696969696969697;, score=(train=-3675.458, test=-3699.395) total time=   0.0s
# [CV 1/10] END alpha=2.0101010101010104;, score=(train=-3667.663, test=-3768.260) total time=   0.0s
# [CV 2/10] END alpha=2.0101010101010104;, score=(train=-3678.547, test=-3673.721) total time=   0.0s
# [CV 3/10] END alpha=2.0101010101010104;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=2.0101010101010104;, score=(train=-3636.072, test=-4038.061) total time=   0.0s
# [CV 5/10] END alpha=2.0101010101010104;, score=(train=-3690.682, test=-3560.925) total time=   0.0s
# [CV 6/10] END alpha=2.0101010101010104;, score=(train=-3681.290, test=-3646.773) total time=   0.0s
# [CV 7/10] END alpha=2.0101010101010104;, score=(train=-3664.627, test=-3795.635) total time=   0.0s
# [CV 8/10] END alpha=2.0101010101010104;, score=(train=-3706.700, test=-3409.950) total time=   0.0s
# [CV 9/10] END alpha=2.0101010101010104;, score=(train=-3687.499, test=-3589.959) total time=   0.0s
# [CV 10/10] END alpha=2.0101010101010104;, score=(train=-3675.458, test=-3699.396) total time=   0.0s
# [CV 1/10] END alpha=2.0505050505050506;, score=(train=-3667.663, test=-3768.261) total time=   0.0s
# [CV 2/10] END alpha=2.0505050505050506;, score=(train=-3678.547, test=-3673.719) total time=   0.0s
# [CV 3/10] END alpha=2.0505050505050506;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=2.0505050505050506;, score=(train=-3636.072, test=-4038.063) total time=   0.0s
# [CV 5/10] END alpha=2.0505050505050506;, score=(train=-3690.682, test=-3560.925) total time=   0.0s
# [CV 6/10] END alpha=2.0505050505050506;, score=(train=-3681.290, test=-3646.773) total time=   0.0s
# [CV 7/10] END alpha=2.0505050505050506;, score=(train=-3664.627, test=-3795.636) total time=   0.0s
# [CV 8/10] END alpha=2.0505050505050506;, score=(train=-3706.700, test=-3409.948) total time=   0.0s
# [CV 9/10] END alpha=2.0505050505050506;, score=(train=-3687.499, test=-3589.958) total time=   0.0s
# [CV 10/10] END alpha=2.0505050505050506;, score=(train=-3675.458, test=-3699.398) total time=   0.0s
# [CV 1/10] END alpha=2.090909090909091;, score=(train=-3667.663, test=-3768.261) total time=   0.0s
# [CV 2/10] END alpha=2.090909090909091;, score=(train=-3678.547, test=-3673.717) total time=   0.0s
# [CV 3/10] END alpha=2.090909090909091;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=2.090909090909091;, score=(train=-3636.072, test=-4038.066) total time=   0.0s
# [CV 5/10] END alpha=2.090909090909091;, score=(train=-3690.682, test=-3560.925) total time=   0.0s
# [CV 6/10] END alpha=2.090909090909091;, score=(train=-3681.290, test=-3646.774) total time=   0.0s
# [CV 7/10] END alpha=2.090909090909091;, score=(train=-3664.627, test=-3795.636) total time=   0.0s
# [CV 8/10] END alpha=2.090909090909091;, score=(train=-3706.700, test=-3409.946) total time=   0.0s
# [CV 9/10] END alpha=2.090909090909091;, score=(train=-3687.499, test=-3589.957) total time=   0.0s
# [CV 10/10] END alpha=2.090909090909091;, score=(train=-3675.458, test=-3699.399) total time=   0.0s
# [CV 1/10] END alpha=2.1313131313131315;, score=(train=-3667.663, test=-3768.261) total time=   0.0s
# [CV 2/10] END alpha=2.1313131313131315;, score=(train=-3678.547, test=-3673.716) total time=   0.0s
# [CV 3/10] END alpha=2.1313131313131315;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=2.1313131313131315;, score=(train=-3636.072, test=-4038.068) total time=   0.0s
# [CV 5/10] END alpha=2.1313131313131315;, score=(train=-3690.682, test=-3560.925) total time=   0.0s
# [CV 6/10] END alpha=2.1313131313131315;, score=(train=-3681.290, test=-3646.774) total time=   0.0s
# [CV 7/10] END alpha=2.1313131313131315;, score=(train=-3664.627, test=-3795.637) total time=   0.0s
# [CV 8/10] END alpha=2.1313131313131315;, score=(train=-3706.700, test=-3409.944) total time=   0.0s
# [CV 9/10] END alpha=2.1313131313131315;, score=(train=-3687.499, test=-3589.955) total time=   0.0s
# [CV 10/10] END alpha=2.1313131313131315;, score=(train=-3675.458, test=-3699.400) total time=   0.0s
# [CV 1/10] END alpha=2.1717171717171717;, score=(train=-3667.663, test=-3768.262) total time=   0.0s
# [CV 2/10] END alpha=2.1717171717171717;, score=(train=-3678.547, test=-3673.714) total time=   0.0s
# [CV 3/10] END alpha=2.1717171717171717;, score=(train=-3686.321, test=-3601.457) total time=   0.0s
# [CV 4/10] END alpha=2.1717171717171717;, score=(train=-3636.072, test=-4038.071) total time=   0.0s
# [CV 5/10] END alpha=2.1717171717171717;, score=(train=-3690.682, test=-3560.925) total time=   0.0s
# [CV 6/10] END alpha=2.1717171717171717;, score=(train=-3681.290, test=-3646.774) total time=   0.0s
# [CV 7/10] END alpha=2.1717171717171717;, score=(train=-3664.627, test=-3795.637) total time=   0.0s
# [CV 8/10] END alpha=2.1717171717171717;, score=(train=-3706.700, test=-3409.942) total time=   0.0s
# [CV 9/10] END alpha=2.1717171717171717;, score=(train=-3687.499, test=-3589.954) total time=   0.0s
# [CV 10/10] END alpha=2.1717171717171717;, score=(train=-3675.458, test=-3699.401) total time=   0.0s
# [CV 1/10] END alpha=2.212121212121212;, score=(train=-3667.663, test=-3768.262) total time=   0.0s
# [CV 2/10] END alpha=2.212121212121212;, score=(train=-3678.547, test=-3673.712) total time=   0.0s
# [CV 3/10] END alpha=2.212121212121212;, score=(train=-3686.321, test=-3601.458) total time=   0.0s
# [CV 4/10] END alpha=2.212121212121212;, score=(train=-3636.072, test=-4038.073) total time=   0.0s
# [CV 5/10] END alpha=2.212121212121212;, score=(train=-3690.682, test=-3560.924) total time=   0.0s
# [CV 6/10] END alpha=2.212121212121212;, score=(train=-3681.290, test=-3646.775) total time=   0.0s
# [CV 7/10] END alpha=2.212121212121212;, score=(train=-3664.627, test=-3795.637) total time=   0.0s
# [CV 8/10] END alpha=2.212121212121212;, score=(train=-3706.700, test=-3409.940) total time=   0.0s
# [CV 9/10] END alpha=2.212121212121212;, score=(train=-3687.499, test=-3589.952) total time=   0.0s
# [CV 10/10] END alpha=2.212121212121212;, score=(train=-3675.458, test=-3699.402) total time=   0.0s
# [CV 1/10] END alpha=2.2525252525252526;, score=(train=-3667.663, test=-3768.263) total time=   0.0s
# [CV 2/10] END alpha=2.2525252525252526;, score=(train=-3678.547, test=-3673.710) total time=   0.0s
# [CV 3/10] END alpha=2.2525252525252526;, score=(train=-3686.321, test=-3601.458) total time=   0.0s
# [CV 4/10] END alpha=2.2525252525252526;, score=(train=-3636.072, test=-4038.076) total time=   0.0s
# [CV 5/10] END alpha=2.2525252525252526;, score=(train=-3690.682, test=-3560.924) total time=   0.0s
# [CV 6/10] END alpha=2.2525252525252526;, score=(train=-3681.290, test=-3646.775) total time=   0.0s
# [CV 7/10] END alpha=2.2525252525252526;, score=(train=-3664.627, test=-3795.638) total time=   0.0s
# [CV 8/10] END alpha=2.2525252525252526;, score=(train=-3706.700, test=-3409.938) total time=   0.0s
# [CV 9/10] END alpha=2.2525252525252526;, score=(train=-3687.499, test=-3589.951) total time=   0.0s
# [CV 10/10] END alpha=2.2525252525252526;, score=(train=-3675.458, test=-3699.403) total time=   0.0s
# [CV 1/10] END alpha=2.2929292929292933;, score=(train=-3667.663, test=-3768.263) total time=   0.0s
# [CV 2/10] END alpha=2.2929292929292933;, score=(train=-3678.547, test=-3673.708) total time=   0.0s
# [CV 3/10] END alpha=2.2929292929292933;, score=(train=-3686.321, test=-3601.458) total time=   0.0s
# [CV 4/10] END alpha=2.2929292929292933;, score=(train=-3636.072, test=-4038.078) total time=   0.0s
# [CV 5/10] END alpha=2.2929292929292933;, score=(train=-3690.682, test=-3560.924) total time=   0.0s
# [CV 6/10] END alpha=2.2929292929292933;, score=(train=-3681.290, test=-3646.775) total time=   0.0s
# [CV 7/10] END alpha=2.2929292929292933;, score=(train=-3664.627, test=-3795.638) total time=   0.0s
# [CV 8/10] END alpha=2.2929292929292933;, score=(train=-3706.700, test=-3409.936) total time=   0.0s
# [CV 9/10] END alpha=2.2929292929292933;, score=(train=-3687.499, test=-3589.950) total time=   0.0s
# [CV 10/10] END alpha=2.2929292929292933;, score=(train=-3675.458, test=-3699.405) total time=   0.0s
# [CV 1/10] END alpha=2.3333333333333335;, score=(train=-3667.663, test=-3768.263) total time=   0.0s
# [CV 2/10] END alpha=2.3333333333333335;, score=(train=-3678.547, test=-3673.706) total time=   0.0s
# [CV 3/10] END alpha=2.3333333333333335;, score=(train=-3686.321, test=-3601.458) total time=   0.0s
# [CV 4/10] END alpha=2.3333333333333335;, score=(train=-3636.072, test=-4038.081) total time=   0.0s
# [CV 5/10] END alpha=2.3333333333333335;, score=(train=-3690.682, test=-3560.924) total time=   0.0s
# [CV 6/10] END alpha=2.3333333333333335;, score=(train=-3681.290, test=-3646.776) total time=   0.0s
# [CV 7/10] END alpha=2.3333333333333335;, score=(train=-3664.627, test=-3795.639) total time=   0.0s
# [CV 8/10] END alpha=2.3333333333333335;, score=(train=-3706.700, test=-3409.934) total time=   0.0s
# [CV 9/10] END alpha=2.3333333333333335;, score=(train=-3687.499, test=-3589.948) total time=   0.0s
# [CV 10/10] END alpha=2.3333333333333335;, score=(train=-3675.458, test=-3699.406) total time=   0.0s
# [CV 1/10] END alpha=2.3737373737373737;, score=(train=-3667.663, test=-3768.264) total time=   0.0s
# [CV 2/10] END alpha=2.3737373737373737;, score=(train=-3678.547, test=-3673.704) total time=   0.0s
# [CV 3/10] END alpha=2.3737373737373737;, score=(train=-3686.321, test=-3601.458) total time=   0.0s
# [CV 4/10] END alpha=2.3737373737373737;, score=(train=-3636.072, test=-4038.083) total time=   0.0s
# [CV 5/10] END alpha=2.3737373737373737;, score=(train=-3690.682, test=-3560.924) total time=   0.0s
# [CV 6/10] END alpha=2.3737373737373737;, score=(train=-3681.290, test=-3646.776) total time=   0.0s
# [CV 7/10] END alpha=2.3737373737373737;, score=(train=-3664.627, test=-3795.639) total time=   0.0s
# [CV 8/10] END alpha=2.3737373737373737;, score=(train=-3706.700, test=-3409.932) total time=   0.0s
# [CV 9/10] END alpha=2.3737373737373737;, score=(train=-3687.499, test=-3589.947) total time=   0.0s
# [CV 10/10] END alpha=2.3737373737373737;, score=(train=-3675.458, test=-3699.407) total time=   0.0s
# [CV 1/10] END alpha=2.4141414141414144;, score=(train=-3667.663, test=-3768.264) total time=   0.0s
# [CV 2/10] END alpha=2.4141414141414144;, score=(train=-3678.547, test=-3673.702) total time=   0.0s
# [CV 3/10] END alpha=2.4141414141414144;, score=(train=-3686.321, test=-3601.458) total time=   0.0s
# [CV 4/10] END alpha=2.4141414141414144;, score=(train=-3636.072, test=-4038.086) total time=   0.0s
# [CV 5/10] END alpha=2.4141414141414144;, score=(train=-3690.682, test=-3560.924) total time=   0.0s
# [CV 6/10] END alpha=2.4141414141414144;, score=(train=-3681.290, test=-3646.777) total time=   0.0s
# [CV 7/10] END alpha=2.4141414141414144;, score=(train=-3664.627, test=-3795.640) total time=   0.0s
# [CV 8/10] END alpha=2.4141414141414144;, score=(train=-3706.700, test=-3409.930) total time=   0.0s
# [CV 9/10] END alpha=2.4141414141414144;, score=(train=-3687.499, test=-3589.946) total time=   0.0s
# [CV 10/10] END alpha=2.4141414141414144;, score=(train=-3675.458, test=-3699.408) total time=   0.0s
# [CV 1/10] END alpha=2.4545454545454546;, score=(train=-3667.663, test=-3768.265) total time=   0.0s
# [CV 2/10] END alpha=2.4545454545454546;, score=(train=-3678.547, test=-3673.700) total time=   0.0s
# [CV 3/10] END alpha=2.4545454545454546;, score=(train=-3686.321, test=-3601.458) total time=   0.0s
# [CV 4/10] END alpha=2.4545454545454546;, score=(train=-3636.072, test=-4038.088) total time=   0.0s
# [CV 5/10] END alpha=2.4545454545454546;, score=(train=-3690.682, test=-3560.924) total time=   0.0s
# [CV 6/10] END alpha=2.4545454545454546;, score=(train=-3681.290, test=-3646.777) total time=   0.0s
# [CV 7/10] END alpha=2.4545454545454546;, score=(train=-3664.627, test=-3795.640) total time=   0.0s
# [CV 8/10] END alpha=2.4545454545454546;, score=(train=-3706.700, test=-3409.928) total time=   0.0s
# [CV 9/10] END alpha=2.4545454545454546;, score=(train=-3687.499, test=-3589.944) total time=   0.0s
# [CV 10/10] END alpha=2.4545454545454546;, score=(train=-3675.458, test=-3699.409) total time=   0.0s
# [CV 1/10] END alpha=2.494949494949495;, score=(train=-3667.663, test=-3768.265) total time=   0.0s
# [CV 2/10] END alpha=2.494949494949495;, score=(train=-3678.547, test=-3673.698) total time=   0.0s
# [CV 3/10] END alpha=2.494949494949495;, score=(train=-3686.321, test=-3601.458) total time=   0.0s
# [CV 4/10] END alpha=2.494949494949495;, score=(train=-3636.072, test=-4038.091) total time=   0.0s
# [CV 5/10] END alpha=2.494949494949495;, score=(train=-3690.682, test=-3560.923) total time=   0.0s
# [CV 6/10] END alpha=2.494949494949495;, score=(train=-3681.290, test=-3646.777) total time=   0.0s
# [CV 7/10] END alpha=2.494949494949495;, score=(train=-3664.627, test=-3795.641) total time=   0.0s
# [CV 8/10] END alpha=2.494949494949495;, score=(train=-3706.700, test=-3409.926) total time=   0.0s
# [CV 9/10] END alpha=2.494949494949495;, score=(train=-3687.499, test=-3589.943) total time=   0.0s
# [CV 10/10] END alpha=2.494949494949495;, score=(train=-3675.458, test=-3699.410) total time=   0.0s
# [CV 1/10] END alpha=2.5353535353535355;, score=(train=-3667.663, test=-3768.265) total time=   0.0s
# [CV 2/10] END alpha=2.5353535353535355;, score=(train=-3678.547, test=-3673.696) total time=   0.0s
# [CV 3/10] END alpha=2.5353535353535355;, score=(train=-3686.321, test=-3601.458) total time=   0.0s
# [CV 4/10] END alpha=2.5353535353535355;, score=(train=-3636.072, test=-4038.093) total time=   0.0s
# [CV 5/10] END alpha=2.5353535353535355;, score=(train=-3690.682, test=-3560.923) total time=   0.0s
# [CV 6/10] END alpha=2.5353535353535355;, score=(train=-3681.290, test=-3646.778) total time=   0.0s
# [CV 7/10] END alpha=2.5353535353535355;, score=(train=-3664.628, test=-3795.641) total time=   0.0s
# [CV 8/10] END alpha=2.5353535353535355;, score=(train=-3706.700, test=-3409.924) total time=   0.0s
# [CV 9/10] END alpha=2.5353535353535355;, score=(train=-3687.499, test=-3589.941) total time=   0.0s
# [CV 10/10] END alpha=2.5353535353535355;, score=(train=-3675.458, test=-3699.412) total time=   0.0s
# [CV 1/10] END alpha=2.575757575757576;, score=(train=-3667.663, test=-3768.266) total time=   0.0s
# [CV 2/10] END alpha=2.575757575757576;, score=(train=-3678.547, test=-3673.694) total time=   0.0s
# [CV 3/10] END alpha=2.575757575757576;, score=(train=-3686.321, test=-3601.458) total time=   0.0s
# [CV 4/10] END alpha=2.575757575757576;, score=(train=-3636.072, test=-4038.096) total time=   0.0s
# [CV 5/10] END alpha=2.575757575757576;, score=(train=-3690.682, test=-3560.923) total time=   0.0s
# [CV 6/10] END alpha=2.575757575757576;, score=(train=-3681.290, test=-3646.778) total time=   0.0s
# [CV 7/10] END alpha=2.575757575757576;, score=(train=-3664.628, test=-3795.642) total time=   0.0s
# [CV 8/10] END alpha=2.575757575757576;, score=(train=-3706.700, test=-3409.922) total time=   0.0s
# [CV 9/10] END alpha=2.575757575757576;, score=(train=-3687.499, test=-3589.940) total time=   0.0s
# [CV 10/10] END alpha=2.575757575757576;, score=(train=-3675.458, test=-3699.413) total time=   0.0s
# [CV 1/10] END alpha=2.6161616161616164;, score=(train=-3667.663, test=-3768.266) total time=   0.0s
# [CV 2/10] END alpha=2.6161616161616164;, score=(train=-3678.547, test=-3673.693) total time=   0.0s
# [CV 3/10] END alpha=2.6161616161616164;, score=(train=-3686.321, test=-3601.458) total time=   0.0s
# [CV 4/10] END alpha=2.6161616161616164;, score=(train=-3636.072, test=-4038.098) total time=   0.0s
# [CV 5/10] END alpha=2.6161616161616164;, score=(train=-3690.682, test=-3560.923) total time=   0.0s
# [CV 6/10] END alpha=2.6161616161616164;, score=(train=-3681.290, test=-3646.778) total time=   0.0s
# [CV 7/10] END alpha=2.6161616161616164;, score=(train=-3664.628, test=-3795.642) total time=   0.0s
# [CV 8/10] END alpha=2.6161616161616164;, score=(train=-3706.700, test=-3409.919) total time=   0.0s
# [CV 9/10] END alpha=2.6161616161616164;, score=(train=-3687.499, test=-3589.939) total time=   0.0s
# [CV 10/10] END alpha=2.6161616161616164;, score=(train=-3675.458, test=-3699.414) total time=   0.0s
# [CV 1/10] END alpha=2.6565656565656566;, score=(train=-3667.663, test=-3768.267) total time=   0.0s
# [CV 2/10] END alpha=2.6565656565656566;, score=(train=-3678.547, test=-3673.691) total time=   0.0s
# [CV 3/10] END alpha=2.6565656565656566;, score=(train=-3686.321, test=-3601.458) total time=   0.0s
# [CV 4/10] END alpha=2.6565656565656566;, score=(train=-3636.072, test=-4038.101) total time=   0.0s
# [CV 5/10] END alpha=2.6565656565656566;, score=(train=-3690.682, test=-3560.923) total time=   0.0s
# [CV 6/10] END alpha=2.6565656565656566;, score=(train=-3681.290, test=-3646.779) total time=   0.0s
# [CV 7/10] END alpha=2.6565656565656566;, score=(train=-3664.628, test=-3795.642) total time=   0.0s
# [CV 8/10] END alpha=2.6565656565656566;, score=(train=-3706.700, test=-3409.917) total time=   0.0s
# [CV 9/10] END alpha=2.6565656565656566;, score=(train=-3687.499, test=-3589.937) total time=   0.0s
# [CV 10/10] END alpha=2.6565656565656566;, score=(train=-3675.458, test=-3699.415) total time=   0.0s
# [CV 1/10] END alpha=2.6969696969696972;, score=(train=-3667.663, test=-3768.267) total time=   0.0s
# [CV 2/10] END alpha=2.6969696969696972;, score=(train=-3678.547, test=-3673.689) total time=   0.0s
# [CV 3/10] END alpha=2.6969696969696972;, score=(train=-3686.321, test=-3601.458) total time=   0.0s
# [CV 4/10] END alpha=2.6969696969696972;, score=(train=-3636.072, test=-4038.103) total time=   0.0s
# [CV 5/10] END alpha=2.6969696969696972;, score=(train=-3690.682, test=-3560.923) total time=   0.0s
# [CV 6/10] END alpha=2.6969696969696972;, score=(train=-3681.290, test=-3646.779) total time=   0.0s
# [CV 7/10] END alpha=2.6969696969696972;, score=(train=-3664.628, test=-3795.643) total time=   0.0s
# [CV 8/10] END alpha=2.6969696969696972;, score=(train=-3706.700, test=-3409.915) total time=   0.0s
# [CV 9/10] END alpha=2.6969696969696972;, score=(train=-3687.499, test=-3589.936) total time=   0.0s
# [CV 10/10] END alpha=2.6969696969696972;, score=(train=-3675.458, test=-3699.416) total time=   0.0s
# [CV 1/10] END alpha=2.7373737373737375;, score=(train=-3667.663, test=-3768.267) total time=   0.0s
# [CV 2/10] END alpha=2.7373737373737375;, score=(train=-3678.547, test=-3673.687) total time=   0.0s
# [CV 3/10] END alpha=2.7373737373737375;, score=(train=-3686.321, test=-3601.458) total time=   0.0s
# [CV 4/10] END alpha=2.7373737373737375;, score=(train=-3636.072, test=-4038.106) total time=   0.0s
# [CV 5/10] END alpha=2.7373737373737375;, score=(train=-3690.682, test=-3560.922) total time=   0.0s
# [CV 6/10] END alpha=2.7373737373737375;, score=(train=-3681.290, test=-3646.779) total time=   0.0s
# [CV 7/10] END alpha=2.7373737373737375;, score=(train=-3664.628, test=-3795.643) total time=   0.0s
# [CV 8/10] END alpha=2.7373737373737375;, score=(train=-3706.700, test=-3409.913) total time=   0.0s
# [CV 9/10] END alpha=2.7373737373737375;, score=(train=-3687.499, test=-3589.934) total time=   0.0s
# [CV 10/10] END alpha=2.7373737373737375;, score=(train=-3675.458, test=-3699.417) total time=   0.0s
# [CV 1/10] END alpha=2.7777777777777777;, score=(train=-3667.663, test=-3768.268) total time=   0.0s
# [CV 2/10] END alpha=2.7777777777777777;, score=(train=-3678.547, test=-3673.685) total time=   0.0s
# [CV 3/10] END alpha=2.7777777777777777;, score=(train=-3686.321, test=-3601.458) total time=   0.0s
# [CV 4/10] END alpha=2.7777777777777777;, score=(train=-3636.072, test=-4038.108) total time=   0.0s
# [CV 5/10] END alpha=2.7777777777777777;, score=(train=-3690.682, test=-3560.922) total time=   0.0s
# [CV 6/10] END alpha=2.7777777777777777;, score=(train=-3681.290, test=-3646.780) total time=   0.0s
# [CV 7/10] END alpha=2.7777777777777777;, score=(train=-3664.628, test=-3795.644) total time=   0.0s
# [CV 8/10] END alpha=2.7777777777777777;, score=(train=-3706.700, test=-3409.911) total time=   0.0s
# [CV 9/10] END alpha=2.7777777777777777;, score=(train=-3687.499, test=-3589.933) total time=   0.0s
# [CV 10/10] END alpha=2.7777777777777777;, score=(train=-3675.459, test=-3699.419) total time=   0.0s
# [CV 1/10] END alpha=2.8181818181818183;, score=(train=-3667.663, test=-3768.268) total time=   0.0s
# [CV 2/10] END alpha=2.8181818181818183;, score=(train=-3678.547, test=-3673.683) total time=   0.0s
# [CV 3/10] END alpha=2.8181818181818183;, score=(train=-3686.321, test=-3601.458) total time=   0.0s
# [CV 4/10] END alpha=2.8181818181818183;, score=(train=-3636.072, test=-4038.111) total time=   0.0s
# [CV 5/10] END alpha=2.8181818181818183;, score=(train=-3690.682, test=-3560.922) total time=   0.0s
# [CV 6/10] END alpha=2.8181818181818183;, score=(train=-3681.290, test=-3646.780) total time=   0.0s
# [CV 7/10] END alpha=2.8181818181818183;, score=(train=-3664.628, test=-3795.644) total time=   0.0s
# [CV 8/10] END alpha=2.8181818181818183;, score=(train=-3706.700, test=-3409.909) total time=   0.0s
# [CV 9/10] END alpha=2.8181818181818183;, score=(train=-3687.499, test=-3589.932) total time=   0.0s
# [CV 10/10] END alpha=2.8181818181818183;, score=(train=-3675.459, test=-3699.420) total time=   0.0s
# [CV 1/10] END alpha=2.858585858585859;, score=(train=-3667.663, test=-3768.269) total time=   0.0s
# [CV 2/10] END alpha=2.858585858585859;, score=(train=-3678.547, test=-3673.681) total time=   0.0s
# [CV 3/10] END alpha=2.858585858585859;, score=(train=-3686.321, test=-3601.458) total time=   0.0s
# [CV 4/10] END alpha=2.858585858585859;, score=(train=-3636.072, test=-4038.113) total time=   0.0s
# [CV 5/10] END alpha=2.858585858585859;, score=(train=-3690.682, test=-3560.922) total time=   0.0s
# [CV 6/10] END alpha=2.858585858585859;, score=(train=-3681.290, test=-3646.780) total time=   0.0s
# [CV 7/10] END alpha=2.858585858585859;, score=(train=-3664.628, test=-3795.645) total time=   0.0s
# [CV 8/10] END alpha=2.858585858585859;, score=(train=-3706.700, test=-3409.907) total time=   0.0s
# [CV 9/10] END alpha=2.858585858585859;, score=(train=-3687.499, test=-3589.930) total time=   0.0s
# [CV 10/10] END alpha=2.858585858585859;, score=(train=-3675.459, test=-3699.421) total time=   0.0s
# [CV 1/10] END alpha=2.8989898989898992;, score=(train=-3667.663, test=-3768.269) total time=   0.0s
# [CV 2/10] END alpha=2.8989898989898992;, score=(train=-3678.547, test=-3673.679) total time=   0.0s
# [CV 3/10] END alpha=2.8989898989898992;, score=(train=-3686.321, test=-3601.459) total time=   0.0s
# [CV 4/10] END alpha=2.8989898989898992;, score=(train=-3636.072, test=-4038.116) total time=   0.0s
# [CV 5/10] END alpha=2.8989898989898992;, score=(train=-3690.682, test=-3560.922) total time=   0.0s
# [CV 6/10] END alpha=2.8989898989898992;, score=(train=-3681.290, test=-3646.781) total time=   0.0s
# [CV 7/10] END alpha=2.8989898989898992;, score=(train=-3664.628, test=-3795.645) total time=   0.0s
# [CV 8/10] END alpha=2.8989898989898992;, score=(train=-3706.700, test=-3409.905) total time=   0.0s
# [CV 9/10] END alpha=2.8989898989898992;, score=(train=-3687.499, test=-3589.929) total time=   0.0s
# [CV 10/10] END alpha=2.8989898989898992;, score=(train=-3675.459, test=-3699.422) total time=   0.0s
# [CV 1/10] END alpha=2.9393939393939394;, score=(train=-3667.663, test=-3768.269) total time=   0.0s
# ...
# [CV 8/10] END alpha=4.3939393939393945;, score=(train=-3706.701, test=-3409.829) total time=   0.0s
# [CV 9/10] END alpha=4.3939393939393945;, score=(train=-3687.500, test=-3589.878) total time=   0.0s
# [CV 10/10] END alpha=4.3939393939393945;, score=(train=-3675.459, test=-3699.466) total time=   0.0s
# [CV 1/10] END alpha=4.434343434343434;, score=(train=-3667.664, test=-3768.284) total time=   0.0s
# [CV 2/10] END alpha=4.434343434343434;, score=(train=-3678.548, test=-3673.607) total time=   0.0s
# [CV 3/10] END alpha=4.434343434343434;, score=(train=-3686.322, test=-3601.461) total time=   0.0s
# [CV 4/10] END alpha=4.434343434343434;, score=(train=-3636.073, test=-4038.211) total time=   0.0s
# [CV 5/10] END alpha=4.434343434343434;, score=(train=-3690.683, test=-3560.916) total time=   0.0s
# [CV 6/10] END alpha=4.434343434343434;, score=(train=-3681.291, test=-3646.794) total time=   0.0s
# [CV 7/10] END alpha=4.434343434343434;, score=(train=-3664.629, test=-3795.662) total time=   0.0s
# [CV 8/10] END alpha=4.434343434343434;, score=(train=-3706.701, test=-3409.827) total time=   0.0s
# [CV 9/10] END alpha=4.434343434343434;, score=(train=-3687.500, test=-3589.877) total time=   0.0s
# [CV 10/10] END alpha=4.434343434343434;, score=(train=-3675.459, test=-3699.467) total time=   0.0s
# [CV 1/10] END alpha=4.474747474747475;, score=(train=-3667.664, test=-3768.285) total time=   0.0s
# [CV 2/10] END alpha=4.474747474747475;, score=(train=-3678.548, test=-3673.605) total time=   0.0s
# [CV 3/10] END alpha=4.474747474747475;, score=(train=-3686.322, test=-3601.461) total time=   0.0s
# [CV 4/10] END alpha=4.474747474747475;, score=(train=-3636.073, test=-4038.213) total time=   0.0s
# [CV 5/10] END alpha=4.474747474747475;, score=(train=-3690.683, test=-3560.916) total time=   0.0s
# [CV 6/10] END alpha=4.474747474747475;, score=(train=-3681.291, test=-3646.795) total time=   0.0s
# [CV 7/10] END alpha=4.474747474747475;, score=(train=-3664.629, test=-3795.663) total time=   0.0s
# [CV 8/10] END alpha=4.474747474747475;, score=(train=-3706.701, test=-3409.825) total time=   0.0s
# [CV 9/10] END alpha=4.474747474747475;, score=(train=-3687.500, test=-3589.876) total time=   0.0s
# [CV 10/10] END alpha=4.474747474747475;, score=(train=-3675.460, test=-3699.468) total time=   0.0s
# [CV 1/10] END alpha=4.515151515151516;, score=(train=-3667.664, test=-3768.285) total time=   0.0s
# [CV 2/10] END alpha=4.515151515151516;, score=(train=-3678.548, test=-3673.603) total time=   0.0s
# [CV 3/10] END alpha=4.515151515151516;, score=(train=-3686.322, test=-3601.461) total time=   0.0s
# [CV 4/10] END alpha=4.515151515151516;, score=(train=-3636.073, test=-4038.216) total time=   0.0s
# [CV 5/10] END alpha=4.515151515151516;, score=(train=-3690.683, test=-3560.916) total time=   0.0s
# [CV 6/10] END alpha=4.515151515151516;, score=(train=-3681.291, test=-3646.795) total time=   0.0s
# [CV 7/10] END alpha=4.515151515151516;, score=(train=-3664.629, test=-3795.663) total time=   0.0s
# [CV 8/10] END alpha=4.515151515151516;, score=(train=-3706.701, test=-3409.823) total time=   0.0s
# [CV 9/10] END alpha=4.515151515151516;, score=(train=-3687.500, test=-3589.874) total time=   0.0s
# [CV 10/10] END alpha=4.515151515151516;, score=(train=-3675.460, test=-3699.469) total time=   0.0s
# [CV 1/10] END alpha=4.555555555555555;, score=(train=-3667.664, test=-3768.286) total time=   0.0s
# [CV 2/10] END alpha=4.555555555555555;, score=(train=-3678.548, test=-3673.601) total time=   0.0s
# [CV 3/10] END alpha=4.555555555555555;, score=(train=-3686.322, test=-3601.461) total time=   0.0s
# [CV 4/10] END alpha=4.555555555555555;, score=(train=-3636.073, test=-4038.218) total time=   0.0s
# [CV 5/10] END alpha=4.555555555555555;, score=(train=-3690.683, test=-3560.915) total time=   0.0s
# [CV 6/10] END alpha=4.555555555555555;, score=(train=-3681.291, test=-3646.795) total time=   0.0s
# [CV 7/10] END alpha=4.555555555555555;, score=(train=-3664.629, test=-3795.664) total time=   0.0s
# [CV 8/10] END alpha=4.555555555555555;, score=(train=-3706.701, test=-3409.821) total time=   0.0s
# [CV 9/10] END alpha=4.555555555555555;, score=(train=-3687.500, test=-3589.873) total time=   0.0s
# [CV 10/10] END alpha=4.555555555555555;, score=(train=-3675.460, test=-3699.471) total time=   0.0s
# [CV 1/10] END alpha=4.595959595959597;, score=(train=-3667.664, test=-3768.286) total time=   0.0s
# [CV 2/10] END alpha=4.595959595959597;, score=(train=-3678.548, test=-3673.599) total time=   0.0s
# [CV 3/10] END alpha=4.595959595959597;, score=(train=-3686.322, test=-3601.461) total time=   0.0s
# [CV 4/10] END alpha=4.595959595959597;, score=(train=-3636.073, test=-4038.221) total time=   0.0s
# [CV 5/10] END alpha=4.595959595959597;, score=(train=-3690.683, test=-3560.915) total time=   0.0s
# [CV 6/10] END alpha=4.595959595959597;, score=(train=-3681.291, test=-3646.796) total time=   0.0s
# [CV 7/10] END alpha=4.595959595959597;, score=(train=-3664.629, test=-3795.664) total time=   0.0s
# [CV 8/10] END alpha=4.595959595959597;, score=(train=-3706.701, test=-3409.819) total time=   0.0s
# [CV 9/10] END alpha=4.595959595959597;, score=(train=-3687.500, test=-3589.871) total time=   0.0s
# [CV 10/10] END alpha=4.595959595959597;, score=(train=-3675.460, test=-3699.472) total time=   0.0s
# [CV 1/10] END alpha=4.636363636363637;, score=(train=-3667.664, test=-3768.286) total time=   0.0s
# [CV 2/10] END alpha=4.636363636363637;, score=(train=-3678.548, test=-3673.597) total time=   0.0s
# [CV 3/10] END alpha=4.636363636363637;, score=(train=-3686.322, test=-3601.462) total time=   0.0s
# [CV 4/10] END alpha=4.636363636363637;, score=(train=-3636.073, test=-4038.223) total time=   0.0s
# [CV 5/10] END alpha=4.636363636363637;, score=(train=-3690.683, test=-3560.915) total time=   0.0s
# [CV 6/10] END alpha=4.636363636363637;, score=(train=-3681.291, test=-3646.796) total time=   0.0s
# [CV 7/10] END alpha=4.636363636363637;, score=(train=-3664.629, test=-3795.665) total time=   0.0s
# [CV 8/10] END alpha=4.636363636363637;, score=(train=-3706.701, test=-3409.817) total time=   0.0s
# [CV 9/10] END alpha=4.636363636363637;, score=(train=-3687.500, test=-3589.870) total time=   0.0s
# [CV 10/10] END alpha=4.636363636363637;, score=(train=-3675.460, test=-3699.473) total time=   0.0s
# [CV 1/10] END alpha=4.6767676767676765;, score=(train=-3667.664, test=-3768.287) total time=   0.0s
# [CV 2/10] END alpha=4.6767676767676765;, score=(train=-3678.548, test=-3673.595) total time=   0.0s
# [CV 3/10] END alpha=4.6767676767676765;, score=(train=-3686.322, test=-3601.462) total time=   0.0s
# [CV 4/10] END alpha=4.6767676767676765;, score=(train=-3636.073, test=-4038.226) total time=   0.0s
# [CV 5/10] END alpha=4.6767676767676765;, score=(train=-3690.683, test=-3560.915) total time=   0.0s
# [CV 6/10] END alpha=4.6767676767676765;, score=(train=-3681.291, test=-3646.796) total time=   0.0s
# [CV 7/10] END alpha=4.6767676767676765;, score=(train=-3664.629, test=-3795.665) total time=   0.0s
# [CV 8/10] END alpha=4.6767676767676765;, score=(train=-3706.701, test=-3409.815) total time=   0.0s
# [CV 9/10] END alpha=4.6767676767676765;, score=(train=-3687.500, test=-3589.869) total time=   0.0s
# [CV 10/10] END alpha=4.6767676767676765;, score=(train=-3675.460, test=-3699.474) total time=   0.0s
# [CV 1/10] END alpha=4.717171717171718;, score=(train=-3667.664, test=-3768.287) total time=   0.0s
# [CV 2/10] END alpha=4.717171717171718;, score=(train=-3678.548, test=-3673.593) total time=   0.0s
# [CV 3/10] END alpha=4.717171717171718;, score=(train=-3686.322, test=-3601.462) total time=   0.0s
# [CV 4/10] END alpha=4.717171717171718;, score=(train=-3636.074, test=-4038.228) total time=   0.0s
# [CV 5/10] END alpha=4.717171717171718;, score=(train=-3690.683, test=-3560.915) total time=   0.0s
# [CV 6/10] END alpha=4.717171717171718;, score=(train=-3681.292, test=-3646.797) total time=   0.0s
# [CV 7/10] END alpha=4.717171717171718;, score=(train=-3664.629, test=-3795.666) total time=   0.0s
# [CV 8/10] END alpha=4.717171717171718;, score=(train=-3706.701, test=-3409.813) total time=   0.0s
# [CV 9/10] END alpha=4.717171717171718;, score=(train=-3687.500, test=-3589.867) total time=   0.0s
# [CV 10/10] END alpha=4.717171717171718;, score=(train=-3675.460, test=-3699.475) total time=   0.0s
# [CV 1/10] END alpha=4.757575757575758;, score=(train=-3667.664, test=-3768.288) total time=   0.0s
# [CV 2/10] END alpha=4.757575757575758;, score=(train=-3678.548, test=-3673.591) total time=   0.0s
# [CV 3/10] END alpha=4.757575757575758;, score=(train=-3686.322, test=-3601.462) total time=   0.0s
# [CV 4/10] END alpha=4.757575757575758;, score=(train=-3636.074, test=-4038.231) total time=   0.0s
# [CV 5/10] END alpha=4.757575757575758;, score=(train=-3690.683, test=-3560.915) total time=   0.0s
# [CV 6/10] END alpha=4.757575757575758;, score=(train=-3681.292, test=-3646.797) total time=   0.0s
# [CV 7/10] END alpha=4.757575757575758;, score=(train=-3664.629, test=-3795.666) total time=   0.0s
# [CV 8/10] END alpha=4.757575757575758;, score=(train=-3706.701, test=-3409.810) total time=   0.0s
# [CV 9/10] END alpha=4.757575757575758;, score=(train=-3687.500, test=-3589.866) total time=   0.0s
# [CV 10/10] END alpha=4.757575757575758;, score=(train=-3675.460, test=-3699.476) total time=   0.0s
# [CV 1/10] END alpha=4.7979797979797985;, score=(train=-3667.664, test=-3768.288) total time=   0.0s
# [CV 2/10] END alpha=4.7979797979797985;, score=(train=-3678.548, test=-3673.589) total time=   0.0s
# [CV 3/10] END alpha=4.7979797979797985;, score=(train=-3686.322, test=-3601.462) total time=   0.0s
# [CV 4/10] END alpha=4.7979797979797985;, score=(train=-3636.074, test=-4038.233) total time=   0.0s
# [CV 5/10] END alpha=4.7979797979797985;, score=(train=-3690.683, test=-3560.915) total time=   0.0s
# [CV 6/10] END alpha=4.7979797979797985;, score=(train=-3681.292, test=-3646.797) total time=   0.0s
# [CV 7/10] END alpha=4.7979797979797985;, score=(train=-3664.629, test=-3795.667) total time=   0.0s
# [CV 8/10] END alpha=4.7979797979797985;, score=(train=-3706.701, test=-3409.808) total time=   0.0s
# [CV 9/10] END alpha=4.7979797979797985;, score=(train=-3687.500, test=-3589.865) total time=   0.0s
# [CV 10/10] END alpha=4.7979797979797985;, score=(train=-3675.460, test=-3699.478) total time=   0.0s
# [CV 1/10] END alpha=4.838383838383839;, score=(train=-3667.664, test=-3768.288) total time=   0.0s
# [CV 2/10] END alpha=4.838383838383839;, score=(train=-3678.548, test=-3673.588) total time=   0.0s
# [CV 3/10] END alpha=4.838383838383839;, score=(train=-3686.322, test=-3601.462) total time=   0.0s
# [CV 4/10] END alpha=4.838383838383839;, score=(train=-3636.074, test=-4038.236) total time=   0.0s
# [CV 5/10] END alpha=4.838383838383839;, score=(train=-3690.683, test=-3560.914) total time=   0.0s
# [CV 6/10] END alpha=4.838383838383839;, score=(train=-3681.292, test=-3646.798) total time=   0.0s
# [CV 7/10] END alpha=4.838383838383839;, score=(train=-3664.629, test=-3795.667) total time=   0.0s
# [CV 8/10] END alpha=4.838383838383839;, score=(train=-3706.701, test=-3409.806) total time=   0.0s
# [CV 9/10] END alpha=4.838383838383839;, score=(train=-3687.500, test=-3589.863) total time=   0.0s
# [CV 10/10] END alpha=4.838383838383839;, score=(train=-3675.460, test=-3699.479) total time=   0.0s
# [CV 1/10] END alpha=4.878787878787879;, score=(train=-3667.664, test=-3768.289) total time=   0.0s
# [CV 2/10] END alpha=4.878787878787879;, score=(train=-3678.548, test=-3673.586) total time=   0.0s
# [CV 3/10] END alpha=4.878787878787879;, score=(train=-3686.322, test=-3601.462) total time=   0.0s
# [CV 4/10] END alpha=4.878787878787879;, score=(train=-3636.074, test=-4038.238) total time=   0.0s
# [CV 5/10] END alpha=4.878787878787879;, score=(train=-3690.683, test=-3560.914) total time=   0.0s
# [CV 6/10] END alpha=4.878787878787879;, score=(train=-3681.292, test=-3646.798) total time=   0.0s
# [CV 7/10] END alpha=4.878787878787879;, score=(train=-3664.629, test=-3795.667) total time=   0.0s
# [CV 8/10] END alpha=4.878787878787879;, score=(train=-3706.701, test=-3409.804) total time=   0.0s
# [CV 9/10] END alpha=4.878787878787879;, score=(train=-3687.501, test=-3589.862) total time=   0.0s
# [CV 10/10] END alpha=4.878787878787879;, score=(train=-3675.460, test=-3699.480) total time=   0.0s
# [CV 1/10] END alpha=4.91919191919192;, score=(train=-3667.664, test=-3768.289) total time=   0.0s
# [CV 2/10] END alpha=4.91919191919192;, score=(train=-3678.548, test=-3673.584) total time=   0.0s
# [CV 3/10] END alpha=4.91919191919192;, score=(train=-3686.323, test=-3601.462) total time=   0.0s
# [CV 4/10] END alpha=4.91919191919192;, score=(train=-3636.074, test=-4038.241) total time=   0.0s
# [CV 5/10] END alpha=4.91919191919192;, score=(train=-3690.683, test=-3560.914) total time=   0.0s
# [CV 6/10] END alpha=4.91919191919192;, score=(train=-3681.292, test=-3646.799) total time=   0.0s
# [CV 7/10] END alpha=4.91919191919192;, score=(train=-3664.629, test=-3795.668) total time=   0.0s
# [CV 8/10] END alpha=4.91919191919192;, score=(train=-3706.701, test=-3409.802) total time=   0.0s
# [CV 9/10] END alpha=4.91919191919192;, score=(train=-3687.501, test=-3589.861) total time=   0.0s
# [CV 10/10] END alpha=4.91919191919192;, score=(train=-3675.460, test=-3699.481) total time=   0.0s
# [CV 1/10] END alpha=4.95959595959596;, score=(train=-3667.664, test=-3768.290) total time=   0.0s
# [CV 2/10] END alpha=4.95959595959596;, score=(train=-3678.548, test=-3673.582) total time=   0.0s
# [CV 3/10] END alpha=4.95959595959596;, score=(train=-3686.323, test=-3601.462) total time=   0.0s
# [CV 4/10] END alpha=4.95959595959596;, score=(train=-3636.074, test=-4038.243) total time=   0.0s
# [CV 5/10] END alpha=4.95959595959596;, score=(train=-3690.683, test=-3560.914) total time=   0.0s
# [CV 6/10] END alpha=4.95959595959596;, score=(train=-3681.292, test=-3646.799) total time=   0.0s
# [CV 7/10] END alpha=4.95959595959596;, score=(train=-3664.629, test=-3795.668) total time=   0.0s
# [CV 8/10] END alpha=4.95959595959596;, score=(train=-3706.701, test=-3409.800) total time=   0.0s
# [CV 9/10] END alpha=4.95959595959596;, score=(train=-3687.501, test=-3589.859) total time=   0.0s
# [CV 10/10] END alpha=4.95959595959596;, score=(train=-3675.460, test=-3699.482) total time=   0.0s
# [CV 1/10] END alpha=5.0;, score=(train=-3667.664, test=-3768.290) total time=   0.0s
# [CV 2/10] END alpha=5.0;, score=(train=-3678.548, test=-3673.580) total time=   0.0s
# [CV 3/10] END alpha=5.0;, score=(train=-3686.323, test=-3601.462) total time=   0.0s
# [CV 4/10] END alpha=5.0;, score=(train=-3636.074, test=-4038.246) total time=   0.0s
# [CV 5/10] END alpha=5.0;, score=(train=-3690.683, test=-3560.914) total time=   0.0s
# [CV 6/10] END alpha=5.0;, score=(train=-3681.292, test=-3646.799) total time=   0.0s
# [CV 7/10] END alpha=5.0;, score=(train=-3664.629, test=-3795.669) total time=   0.0s
# [CV 8/10] END alpha=5.0;, score=(train=-3706.701, test=-3409.798) total time=   0.0s
# [CV 9/10] END alpha=5.0;, score=(train=-3687.501, test=-3589.858) total time=   0.0s
# [CV 10/10] END alpha=5.0;, score=(train=-3675.460, test=-3699.484) total time=   0.0s
# GridSearchCV(cv=10, estimator=Ridge(),
#              param_grid={'alpha': array([1.        , 1.04040404, 1.08080808, 1.12121212, 1.16161616,
#        1.2020202 , 1.24242424, 1.28282828, 1.32323232, 1.36363636,
#        1.4040404 , 1.44444444, 1.48484848, 1.52525253, 1.56565657,
#        1.60606061, 1.64646465, 1.68686869, 1.72727273, 1.76767677,
#        1.80808081, 1.84848485, 1.88888889, 1.92929293, 1.96969697,
#        2.01010101, 2.05050505...
#        3.82828283, 3.86868687, 3.90909091, 3.94949495, 3.98989899,
#        4.03030303, 4.07070707, 4.11111111, 4.15151515, 4.19191919,
#        4.23232323, 4.27272727, 4.31313131, 4.35353535, 4.39393939,
#        4.43434343, 4.47474747, 4.51515152, 4.55555556, 4.5959596 ,
#        4.63636364, 4.67676768, 4.71717172, 4.75757576, 4.7979798 ,
#        4.83838384, 4.87878788, 4.91919192, 4.95959596, 5.        ])},
#              return_train_score=True, scoring='neg_root_mean_squared_error',
#              verbose=3)

# %%
y_pred = grid_ridge.predict(X_test_scaled)

# %%
R2_score = r2_score(y_test,y_pred)
R2_score
# Out:
# 0.7598214195498108

# %%
grid_ridge.best_params_
# Out:
# {'alpha': 5.0}

# %% [markdown]
# # Implement Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
lasso_model = Lasso()

# %%
grid_lasso = GridSearchCV(estimator=lasso_model,
                          param_grid=param_grid,
                          scoring='neg_root_mean_squared_error',
                          cv=10,
                          verbose=1,
                          return_train_score=True)

# %%
grid_lasso.fit(X_train_scaled, y_train)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# GridSearchCV(cv=10, estimator=Lasso(),
#              param_grid={'alpha': array([1.        , 1.01010101, 1.02020202, 1.03030303, 1.04040404,
#        1.05050505, 1.06060606, 1.07070707, 1.08080808, 1.09090909,
#        1.1010101 , 1.11111111, 1.12121212, 1.13131313, 1.14141414,
#        1.15151515, 1.16161616, 1.17171717, 1.18181818, 1.19191919,
#        1.2020202 , 1.21212121, 1.22222222, 1.23232323, 1.24242424,
#        1.25252525, 1.26262626...
#        1.70707071, 1.71717172, 1.72727273, 1.73737374, 1.74747475,
#        1.75757576, 1.76767677, 1.77777778, 1.78787879, 1.7979798 ,
#        1.80808081, 1.81818182, 1.82828283, 1.83838384, 1.84848485,
#        1.85858586, 1.86868687, 1.87878788, 1.88888889, 1.8989899 ,
#        1.90909091, 1.91919192, 1.92929293, 1.93939394, 1.94949495,
#        1.95959596, 1.96969697, 1.97979798, 1.98989899, 2.        ])},
#              return_train_score=True, scoring='neg_root_mean_squared_error',
#              verbose=1)

# %%
grid_lasso.best_params_
# Out:
# {'alpha': 2.0}

# %%
y_pred = grid_lasso.predict(X_test_scaled)
y_train_pred = grid_lasso.predict(X_train_scaled)

# %%
lgs = train_val(y_train, y_train_pred, y_test, y_pred, "grid_lasso")
lgs
# Out:
#       grid_lasso_train  grid_lasso_test
# R2        7.513879e-01     7.598303e-01
# mae       2.723668e+03     2.751895e+03
# mse       1.352585e+07     1.385534e+07
# rmse      3.677751e+03     3.722276e+03

# %%
from yellowbrick.model_selection import FeatureImportances
from yellowbrick.features import RadViz

model = Lasso(alpha=0.01)

viz = FeatureImportances(model, labels=pd.DataFrame(X_train).columns)
visualizer = RadViz(size=(720, 3000))
viz.fit(X_train_scaled, y_train)
viz.show();

# %% [markdown]
# # Implement Elastic-Net

# %% [markdown]
# # Feature Importance

# %% [markdown]
# # Compare Models Performance

# %% [markdown]
# # Final Model

# %% [markdown]
# # Prediction with new observation

# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:100%;color:white;text-align:center;border-radius:20px 20px;"><b>Faydalı Olması Temennisiyle Teşekkürler</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [WhatsApp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [LinkedIn](https://www.linkedin.com/company/techproeducation/mycompany/) |
